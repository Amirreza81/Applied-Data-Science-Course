# %% [markdown]
# <div style="text-align: center;">
#     <h1>Applied Data Science</h1>
#     <h3><em>Spring 2025</em></h3>
#     <h2>Assignment 2 - Exploratory Analysis and Data Cleaning</h2>
#     <hr style="width:60%;">
#     <h3>AmirReza Azari</h3>
#     <p><em>Student ID: 99101087</em></p>
# </div>
#
# ---

# %% [markdown]
# # Table of Contents
# - [Introduction](##Introduction)
# - [Loading the Dataset](##Loading\the\Dataset)
# - [Data Cleaning](##Data\Cleaning)
#   - [Handlig Missing Values](####Handling\Missing\Values)
#   - [Invalid Data](####Invalid\Data)
#   - [Dealing with duplicate data](##Dealing\with\duplicate\data)
# - [Data Preprocessing](##Data\Preprocessing)
# - [Normalization/Stadardization](##NormalizationStadardization)
# - [Correlation Analysis](##Correlation\Analysis)
# ---

# %% [markdown]
# ## Introduction:

# %% [markdown]
# In this assignment I will work on [Stroke Prediction Dataset](https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset). According to the World Health Organization (WHO) stroke is the 2nd leading cause of death globally, responsible for approximately 11% of total deaths.
# This dataset is used to predict whether a patient is likely to get stroke based on the input parameters like gender, age, various diseases, and smoking status. Each row in the data provides relavant information about the patient.

# %% [markdown]
# ## Loading the Dataset
# I can load and read the .csv file but I want to load the dataset from kaggle.

# %%
# First, let's import the libraries we'll need later
import pandas as pd
import io
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline
sns.set(color_codes=True)

# %%
# Then, let's install Kaggle
# !python -m pip install kaggle #==1.5.6
# !kaggle -v
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.11/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.10)
# Kaggle API 1.6.17

# %%
# !python -m pip install jupyter-dash
# Out:
# Requirement already satisfied: jupyter-dash in /usr/local/lib/python3.11/dist-packages (0.4.2)
# Requirement already satisfied: dash in /usr/local/lib/python3.11/dist-packages (from jupyter-dash) (2.18.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from jupyter-dash) (2.32.3)
# Requirement already satisfied: flask in /usr/local/lib/python3.11/dist-packages (from jupyter-dash) (3.0.3)
# Requirement already satisfied: retrying in /usr/local/lib/python3.11/dist-packages (from jupyter-dash) (1.3.4)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from jupyter-dash) (7.34.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from jupyter-dash) (6.17.1)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.11/dist-packages (from jupyter-dash) (1.9.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from jupyter-dash) (1.6.0)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.11/dist-packages (from dash->jupyter-dash) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from dash->jupyter-dash) (5.24.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.11/dist-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.11/dist-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.11/dist-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash->jupyter-dash) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash->jupyter-dash) (4.12.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash->jupyter-dash) (75.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask->jupyter-dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from flask->jupyter-dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from flask->jupyter-dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from flask->jupyter-dash) (1.9.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter-dash) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter-dash) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter-dash) (0.1.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter-dash) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter-dash) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter-dash) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter-dash) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter-dash) (5.7.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython->jupyter-dash) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->jupyter-dash) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->jupyter-dash) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->jupyter-dash) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->jupyter-dash) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->jupyter-dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->jupyter-dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->jupyter-dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->jupyter-dash) (2025.1.31)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from retrying->jupyter-dash) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->flask->jupyter-dash) (3.0.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (5.7.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash->jupyter-dash) (9.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.13)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash->jupyter-dash) (3.21.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel->jupyter-dash) (4.3.6)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"

# %%
# %cd /content/gdrive/My Drive/Kaggle
# Out:
# /content/gdrive/My Drive/Kaggle

# %%
# !kaggle datasets download -d fedesoriano/stroke-prediction-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset
# License(s): copyright-authors
# stroke-prediction-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip \*.zip
# Out:
# Archive:  stroke-prediction-dataset.zip
# replace healthcare-dataset-stroke-data.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: healthcare-dataset-stroke-data.csv

# %% [markdown]
# Next step would be to load the CSV file into a Pandas dataframe.

# %%
df = pd.read_csv('healthcare-dataset-stroke-data.csv')

# %% [markdown]
# Now let's take a look at the first 5 rows of the data:

# %%
df.shape
# Out:
# (5110, 12)

# %%
list(df.columns)
# Out:
# ['id',
#  'gender',
#  'age',
#  'hypertension',
#  'heart_disease',
#  'ever_married',
#  'work_type',
#  'Residence_type',
#  'avg_glucose_level',
#  'bmi',
#  'smoking_status',
#  'stroke']

# %%
df.head() # After using colab feature to see some visualization.
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
df.sort_values(by='age', ascending=False).tail(10)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married work_type  \
# 2898  64974    Male  0.24             0              0           No  children
# 4293  69222    Male  0.24             0              0           No  children
# 1999  42500    Male  0.24             0              0           No  children
# 3392  11371    Male  0.24             0              0           No  children
# 996   53279    Male  0.24             0              0           No  children
# 3618  22877    Male  0.16             0              0           No  children
# 3968  41500    Male  0.16             0              0           No  children
# 4021   8247    Male  0.16             0              0           No  children
# 1614  47350  Female  0.08             0              0           No  children
# 3295  29955    Male  0.08             0              0           No  children
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 2898          Urban              58.35  18.6        Unknown       0
# 4293          Urban              57.09  19.4        Unknown       0
# 1999          Rural             146.97  18.5        Unknown       0
# 3392          Urban              89.28  14.2        Unknown       0
# 996           Rural             118.87  16.3        Unknown       0
# 3618          Urban             114.71  17.4        Unknown       0
# 3968          Rural              69.79  13.0        Unknown       0
# 4021          Urban             109.52  13.9        Unknown       0
# 1614          Urban             139.67  14.1        Unknown       0
# 3295          Rural              70.33  16.9        Unknown       0

# %%
# @title gender vs ever_married

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['ever_married'].value_counts()
    for x_label, grp in df.groupby('gender')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('gender')
_ = plt.ylabel('ever_married')

# %%
# @title Residence_type

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Residence_type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title work_type

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('work_type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title ever_married

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('ever_married').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title gender

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title age

from matplotlib import pyplot as plt
df['age'].plot(kind='hist', bins=20, title='age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# And here's a summary of the dataset as a whole. It shows us the columns, their datatype, and how many values in that column are null (empty/missing data).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# Another useful method is "describe", which shows a summary of the columns from a statistics point of view, i.e. max, min, mean and standard deviation of values.

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %% [markdown]
# ## Getting Some Insights from Our Data

# %% [markdown]
# First, let's check the percentage of genders:

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))

# Define custom colors for better aesthetics
colors = ['#ff9999', '#66b3ff']

# Highlight the first slice slightly
n = list(df['gender'].unique())
explode = [0.05] * (len(n))

df['gender'].value_counts().plot.pie(
    autopct='%1.1f%%',  # Display percentage values
    startangle=90,  # Rotate for better alignment
    colors=colors,  # Apply custom colors
    explode=explode,  # Add slight separation to first slice
    wedgeprops={'edgecolor': 'black', 'linewidth': 1.5}  # Enhance edge visibility
)

plt.title('Gender Distribution', fontsize=14, fontweight='bold')
plt.ylabel('')
plt.show()

# %% [markdown]
# As you can see, we have 58.6% Female and 41.4% Male and just one 'other' gender that we should find it.

# %%
df[df['gender'] == 'Other']
# Out:
#          id gender   age  hypertension  heart_disease ever_married work_type  \
# 3116  56156  Other  26.0             0              0           No   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 3116          Rural             143.33  22.4  formerly smoked       0

# %% [markdown]
# Now, we will explore about their ages.

# %%
df['age'].describe()
# Out:
# count    5110.000000
# mean       43.226614
# std        22.612647
# min         0.080000
# 25%        25.000000
# 50%        45.000000
# 75%        61.000000
# max        82.000000
# Name: age, dtype: float64

# %% [markdown]
# We have a minimum age of 0.08. I will more explore about this data in data cleaning part. (Maybe Incorrect data)

# %%
# Count unique age values for better visualization
age_counts = df['age'].value_counts().sort_index()

plt.figure(figsize=(18, 8))

# Create bar chart
age_counts.plot(kind='bar', color='skyblue', edgecolor='black')

plt.xlabel('Age', fontsize=10)
plt.ylabel('Count', fontsize=12)
plt.title('Age Distribution', fontsize=14, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# What about the correlation between age and stroke?

# %%
df.plot(kind='scatter', x='age', y='stroke', color='b',figsize=(10, 6))
# Out:
# <Axes: xlabel='age', ylabel='stroke'>

# %% [markdown]
# I am curious about the percentage of strokes in the age of above 50:

# %%
# Filter people over 50 years old
over_50 = df[df['age'] > 50]

# Count stroke cases (True values in 'stroke' column)
stroke_count = over_50['stroke'].sum()

# Calculate percentage of strokes in this age group
stroke_percentage = (stroke_count / len(over_50)) * 100

print(f"Percentage of people over 50 who had a stroke: {stroke_percentage:.2f}%")
# Out:
# Percentage of people over 50 who had a stroke: 10.63%

# %% [markdown]
# What about the correlation between age and hypertension?

# %%
df.plot(kind='scatter', x='age', y='hypertension', color='b',figsize=(10, 6))
# Out:
# <Axes: xlabel='age', ylabel='hypertension'>

# %% [markdown]
# Also, I am curious about the percentage of hypertensions in the age of above 50:

# %%
# Filter people over 50 years old
over_50 = df[df['age'] > 50]

# Count hypertension cases (True values in 'hypertension' column)
hypertension_count = over_50['hypertension'].sum()

# Calculate percentage of hypertensions in this age group
hypertension_percentage = (hypertension_count / len(over_50)) * 100

print(f"Percentage of people over 50 who had a Hypertension: {hypertension_percentage:.2f}%")
# Out:
# Percentage of people over 50 who had a Hypertension: 18.95%

# %% [markdown]
# Aprox 10% of the people have hypertension:

# %%
df['hypertension'].value_counts()
# Out:
# hypertension
# 0    4612
# 1     498
# Name: count, dtype: int64

# %% [markdown]
# What about the correlation between age and heart disease?

# %%
df.plot(kind='scatter', x='age', y='heart_disease', color='b',figsize=(10, 6))
# Out:
# <Axes: xlabel='age', ylabel='heart_disease'>

# %% [markdown]
# What about the percentage of heart disease in the age of above 50:

# %%
# Count hypertension cases (True values in 'heart_disease' column)
heart_disease_count = over_50['heart_disease'].sum()

# Calculate percentage of heart disease in this age group
heart_disease_percentage = (heart_disease_count / len(over_50)) * 100

print(f"Percentage of people over 50 who had a heart disease: {heart_disease_percentage:.2f}%")
# Out:
# Percentage of people over 50 who had a heart disease: 12.08%

# %% [markdown]
# Now, let's repeate previouse steps for status of their marriage:

# %%
df['ever_married'].value_counts()
# Out:
# ever_married
# Yes    3353
# No     1757
# Name: count, dtype: int64

# %%
df.plot(kind='scatter', x='age', y='ever_married', color='b',figsize=(10, 6))
# Out:
# <Axes: xlabel='age', ylabel='ever_married'>

# %% [markdown]
# I am curious about the minimum age who is married and the maximum age who is not married :)))

# %%
df[(df['ever_married'] == 'Yes')]['age'].min()
# Out:
# 18.0

# %%
df[(df['ever_married'] == 'No')]['age'].max()
# Out:
# 82.0

# %%
df[(df['age'] == 18) & (df['ever_married'] == 'Yes')]
# Out:
#          id gender   age  hypertension  heart_disease ever_married work_type  \
# 1169  39661   Male  18.0             0              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 1169          Rural             140.52  27.4   never smoked       0

# %%
df[(df['age'] == 82) & (df['ever_married'] == 'No')]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 35      712  Female  82.0             1              1           No
# 337   56357  Female  82.0             0              1           No
# 613   22853    Male  82.0             0              0           No
# 1042  39120  Female  82.0             0              0           No
# 3108  53252    Male  82.0             0              0           No
# 3192  47917  Female  82.0             1              0           No
# 3603  28247    Male  82.0             0              0           No
# 4716   5387  Female  82.0             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 35          Private          Rural              84.03  26.5  formerly smoked
# 337         Private          Urban             215.60  24.9     never smoked
# 613   Self-employed          Rural             106.43  27.0           smokes
# 1042  Self-employed          Urban              82.21  26.0     never smoked
# 3108  Self-employed          Urban             161.95  30.8     never smoked
# 3192        Private          Rural              61.47  22.9     never smoked
# 3603  Self-employed          Urban             101.57  24.3           smokes
# 4716        Private          Rural              96.98  21.5     never smoked
#
#       stroke
# 35         1
# 337        0
# 613        0
# 1042       0
# 3108       0
# 3192       0
# 3603       0
# 4716       0

# %% [markdown]
# Now let's explore the effect of status of marriage in stroke:

# %%
df_married = df[df['ever_married'] == 'Yes']
df_not_married = df[df['ever_married'] == 'No']

# %%
sns.countplot(data=df_married, x='ever_married', hue='stroke', palette=['skyblue', 'salmon'])

# Improve labels and title
plt.xlabel('Marital Status', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Stroke Cases by Marital Status', fontsize=14, fontweight='bold')
plt.legend(title='Stroke', labels=['No', 'Yes'])

plt.show()

# %%
sns.countplot(data=df_not_married, x='ever_married', hue='stroke', palette=['skyblue', 'salmon'])

# Improve labels and title
plt.xlabel('Marital Status', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Stroke Cases by Marital Status', fontsize=14, fontweight='bold')
plt.legend(title='Stroke', labels=['No', 'Yes'])

plt.show()

# %%
# Count values for each group
married_stroke_counts = df.groupby('ever_married')['stroke'].value_counts().unstack()

# Convert to percentage
married_stroke_percentage = (married_stroke_counts.T / married_stroke_counts.T.sum()).T * 100

# Plot stacked bar chart
married_stroke_percentage.plot(kind='bar', stacked=True, figsize=(8,6), color=['skyblue', 'salmon'])

# Improve labels and title
plt.xlabel('Marital Status', fontsize=12)
plt.ylabel('Percentage', fontsize=12)
plt.title('Stacked Bar Chart: Stroke by Marital Status', fontsize=14, fontweight='bold')
plt.legend(title='Stroke', labels=['No', 'Yes'])

plt.show()

# %% [markdown]
# Now, let's explore 'work_type' column:

# %%
df['work_type'].value_counts()
# Out:
# work_type
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: count, dtype: int64

# %%
df['work_type'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Approx same number of urban  and rural:

# %%
df['Residence_type'].value_counts()
# Out:
# Residence_type
# Urban    2596
# Rural    2514
# Name: count, dtype: int64

# %% [markdown]
# Let's know about the glucose level of people:

# %%
df['avg_glucose_level'].describe()
# Out:
# count    5110.000000
# mean      106.147677
# std        45.283560
# min        55.120000
# 25%        77.245000
# 50%        91.885000
# 75%       114.090000
# max       271.740000
# Name: avg_glucose_level, dtype: float64

# %% [markdown]
# The average glucose level (also known as blood glucose level) is a critical measurement for assessing a person's metabolic health. The normal glucose levels can vary based on whether you're fasting, after eating, or during certain health conditions like diabetes.
#
# Generally, 100 mg/dL for fasting blood glucose is considered the borderline between normal and prediabetic levels.

# %%
diabetic_people = df[df['avg_glucose_level'] >= 100]
percentage = (diabetic_people.shape[0] / df.shape[0]) * 100
print(f'The percentage of people suspected to have diabetes: {percentage}%')
# Out:
# The percentage of people suspected to have diabetes: 38.7279843444227%

# %% [markdown]
# Now, BMI:

# %%
df['bmi'].describe()
# Out:
# count    4909.000000
# mean       28.893237
# std         7.854067
# min        10.300000
# 25%        23.500000
# 50%        28.100000
# 75%        33.100000
# max        97.600000
# Name: bmi, dtype: float64

# %% [markdown]
# **BMI Categories:**
# - Underweight: BMI less than 18.5
# - Normal weight: BMI between 18.5 and 24.9
# - Overweight: BMI between 25 and 29.9
# - Obesity: BMI of 30 or more

# %% [markdown]
# When the mean is 28.89 it seem that the average of these people are overweighted!

# %%
df.plot(kind='scatter', x='bmi', y='stroke', color='b',figsize=(10, 6))
# Out:
# <Axes: xlabel='bmi', ylabel='stroke'>

# %%
df['smoking_status'].value_counts()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64

# %%
percentage = df[df['stroke'] == 1].shape[0] / df.shape[0]
print(percentage * 100)
# Out:
# 4.87279843444227

# %%
df_stroke = df['stroke'].value_counts()
my_labels = 'No stroke', 'Stroke'
plt.pie(df_stroke, labels = my_labels, autopct= '%1.1f%%')
plt.title('Stroke %')
plt.axis('equal')
plt.show()

# %% [markdown]
# Let's find out if there are any null values:

# %%
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %% [markdown]
# BMI (Body Mass Index) field seems to have the only null values: 201/5110 = 3.9% of the whole dataset which is negligible but before we remove them from the analysis, let's see if there are any stroke patients among the null BMI since our total stroke percentage is 4.9%:

# %%
len(df[df['bmi'].isna() & df['stroke']==1])
# Out:
# 40

# %% [markdown]
# To get a general sense, let's use heatmap correlation to see how factors correlate to each other:

# %%
sns.heatmap(df[['age', 'bmi', 'avg_glucose_level']].corr(), vmin= -1, vmax= 1, annot = True)
plt.show()

# %% [markdown]
# We see that in general the fields have low correlation with each other. For Stroke, the highest correlation seems to be Age. Next, with Age, BMI field seems to be correlated the highest and then Hypertension and Heart_disease followed by Avg_glucose level. Before we explore these correlated fields further, let's see the distributions of the Numerical fields - Age, BMI, and Avg_glucose_level:

# %%
Age_dis = sns.histplot(df['age'], kde = True)
Age_dis.set_title("Age Distribution")
plt.show()

# %%
BMI_dis = sns.histplot(df['bmi'], kde = True)
BMI_dis.set_title("BMI Distribution")
plt.show()

# %%
Glucose_dis = sns.histplot(df['avg_glucose_level'], kde = True)
Glucose_dis.set_title("Blood sugar Distribution")
plt.show()

# %%
plt.scatter(df['age'], df['bmi'], color='teal')
plt.title('Age vs. BMI')
# Out:
# Text(0.5, 1.0, 'Age vs. BMI')

# %% [markdown]
# There's definitely a correlation between age and BMI which supports the heatmap. Past 50 years of age, the BMI trend does seem to go down and this may be due to our bodies starting to get old and smaller in frame.

# %%
plt.scatter(df['age'], df['avg_glucose_level'], color='greenyellow')
plt.title('Age vs. Blood sugar')
# Out:
# Text(0.5, 1.0, 'Age vs. Blood sugar')

# %% [markdown]
# As for Age vs. Blood sugar, there seems to be a very low positive correlation.

# %%
def bar_chart(attribute):
    return df.groupby([attribute, 'stroke'])['age'].count().unstack().plot.bar(stacked=True, figsize=(4,4), width=0.5)

def stroke_pct(attribute):
    stroke = df.groupby([attribute, 'stroke'])['age'].count()
    total = df.groupby([attribute])['age'].count()
    stroke_pct = stroke/total * 100
    stroke_pct = stroke_pct.unstack()
    return stroke_pct.plot.bar(stacked=True, figsize=(4,4), width=0.5)

# %%
bar_chart('work_type').set_title("Work_type")
stroke_pct('work_type').set_title("Stroke % in Work type")
# Out:
# Text(0.5, 1.0, 'Stroke % in Work type')

# %%
bar_chart('smoking_status').set_title("Smoking Status")
stroke_pct('smoking_status').set_title("Stroke % among Smoking status")
# Out:
# Text(0.5, 1.0, 'Stroke % among Smoking status')

# %% [markdown]
# **EDA Insight & Learnings**:
#
# 1. Age is a strong driving factor for Stroke risk.
# 2. Contrary to my assumption, BMI was not correlated to risk of Stroke. This came as a surprise as BMI is used to diagnose obesity which is linked to other risks like heart disease and stroke.
# 3. Blood sugar was not correlated to stroke risk however, diabetes is a risk for stroke because it raises the risk by 1.5 times if your avg_glucose_level is greater than 200mg/dL reaching the diabetic category and we saw that in this dataset.
# 4. Sometimes what seems to be a correlation on the surface isn't. For example, attributes like Heart disease, hypertension, ever_married and smoking_status all upon further analysis, pointed to age.

# %% [markdown]
# ## Data Cleaning

# %%
# First take a copy from main df
main_df = df.copy()

# %%
main_df.shape
# Out:
# (5110, 12)

# %% [markdown]
# Next step would be to clean the data. We will check for **missing values**, possible **invalid data**, **duplicate rows**.

# %% [markdown]
# #### Handling Missing Values

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# As we said, BMI (Body Mass Index) field seems to have the only null values: 201/5110 = 3.9% of the whole dataset which is negligible but before we remove them from the analysis, let's see if there are any stroke patients among the null BMI since our total stroke percentage is 4.9%:

# %%
len(df[df['bmi'].isna() & df['stroke']==1])
# Out:
# 40

# %% [markdown]
# There are 40 stroke patients among the null BMI values making up 16% of total strokes! so we will NOT remove them and instead maybe will fill in the mean BMI values in order to keep all the stroke counts. Let's first see them:

# %%
df[df['bmi'].isna() & df['stroke']==1]
# Out:
#         id  gender    age  hypertension  heart_disease ever_married  \
# 1    51676  Female  61.00             0              0          Yes
# 8    27419  Female  59.00             0              0          Yes
# 13    8213    Male  78.00             0              1          Yes
# 19   25226    Male  57.00             0              1           No
# 27   61843    Male  58.00             0              0          Yes
# 29   69160    Male  59.00             0              0          Yes
# 43    1845  Female  63.00             0              0          Yes
# 46   37937  Female  75.00             0              1           No
# 50   18587  Female  76.00             0              0           No
# 51   15102    Male  78.00             1              0          Yes
# 54    8752  Female  63.00             0              0          Yes
# 57   66400    Male  78.00             0              0          Yes
# 64    7356    Male  75.00             0              0          Yes
# 70   70676  Female  76.00             0              0          Yes
# 78   45805  Female  51.00             0              0          Yes
# 81   26015  Female  66.00             0              0          Yes
# 84   70042    Male  58.00             0              0          Yes
# 105   2346    Male  58.00             0              0          Yes
# 112  36706  Female  76.00             0              0          Yes
# 124  14164  Female  72.00             0              0          Yes
# 126   3352    Male  78.00             1              0          Yes
# 129  48796  Female  75.00             0              0          Yes
# 133  31563  Female  38.00             0              0          Yes
# 146  41241    Male  65.00             0              0          Yes
# 150  11933  Female  79.00             0              0          Yes
# 160  50931  Female  76.00             0              0          Yes
# 161  16590    Male  71.00             0              1          Yes
# 162  69768  Female   1.32             0              0           No
# 167  43364    Male  79.00             1              0          Yes
# 170  28939    Male  64.00             0              0          Yes
# 171  60739  Female  79.00             1              1           No
# 174  40899  Female  78.00             0              0          Yes
# 178  33486  Female  80.00             0              0          Yes
# 183   8003  Female  77.00             0              0           No
# 189  66955    Male  61.00             0              1          Yes
# 198  18937    Male  79.00             0              0          Yes
# 200  54695    Male  74.00             0              0          Yes
# 218  25904  Female  76.00             1              1          Yes
# 227  39105    Male  74.00             0              0          Yes
# 247  34060    Male  71.00             1              0          Yes
#
#          work_type Residence_type  avg_glucose_level  bmi   smoking_status  \
# 1    Self-employed          Rural             202.21  NaN     never smoked
# 8          Private          Rural              76.15  NaN          Unknown
# 13         Private          Urban             219.84  NaN          Unknown
# 19        Govt_job          Urban             217.08  NaN          Unknown
# 27         Private          Rural             189.84  NaN          Unknown
# 29         Private          Rural             211.78  NaN  formerly smoked
# 43         Private          Urban              90.90  NaN  formerly smoked
# 46   Self-employed          Urban             109.78  NaN          Unknown
# 50         Private          Urban              89.96  NaN          Unknown
# 51         Private          Urban              75.32  NaN  formerly smoked
# 54        Govt_job          Urban             197.54  NaN     never smoked
# 57         Private          Urban             237.75  NaN  formerly smoked
# 64         Private          Urban             104.72  NaN          Unknown
# 70        Govt_job          Rural              62.57  NaN  formerly smoked
# 78         Private          Urban             165.31  NaN     never smoked
# 81   Self-employed          Urban             101.45  NaN          Unknown
# 84         Private          Urban              71.20  NaN          Unknown
# 105        Private          Urban              82.30  NaN           smokes
# 112  Self-employed          Urban             106.41  NaN  formerly smoked
# 124        Private          Urban             219.91  NaN          Unknown
# 126  Self-employed          Urban              93.13  NaN  formerly smoked
# 129       Govt_job          Urban              62.48  NaN          Unknown
# 133        Private          Rural             101.45  NaN  formerly smoked
# 146  Self-employed          Urban              68.43  NaN  formerly smoked
# 150        Private          Rural             169.67  NaN          Unknown
# 160        Private          Urban              57.92  NaN  formerly smoked
# 161        Private          Urban              81.76  NaN           smokes
# 162       children          Urban              70.37  NaN          Unknown
# 167        Private          Rural              75.02  NaN     never smoked
# 170  Self-employed          Rural             111.98  NaN  formerly smoked
# 171  Self-employed          Rural              60.94  NaN     never smoked
# 174  Self-employed          Rural              60.67  NaN  formerly smoked
# 178       Govt_job          Urban             110.66  NaN          Unknown
# 183        Private          Urban              81.32  NaN          Unknown
# 189        Private          Urban             209.86  NaN          Unknown
# 198        Private          Rural             114.77  NaN  formerly smoked
# 200        Private          Urban             167.13  NaN          Unknown
# 218  Self-employed          Urban             199.86  NaN           smokes
# 227  Self-employed          Rural              60.98  NaN     never smoked
# 247  Self-employed          Rural              87.80  NaN          Unknown
#
#      stroke
# 1         1
# 8         1
# 13        1
# 19        1
# 27        1
# 29        1
# 43        1
# 46        1
# 50        1
# 51        1
# 54        1
# 57        1
# 64        1
# 70        1
# 78        1
# 81        1
# 84        1
# 105       1
# 112       1
# 124       1
# 126       1
# 129       1
# 133       1
# 146       1
# 150       1
# 160       1
# 161       1
# 162       1
# 167       1
# 170       1
# 171       1
# 174       1
# 178       1
# 183       1
# 189       1
# 198       1
# 200       1
# 218       1
# 227       1
# 247       1

# %%
id_nan_bmi_list = list(df[df['bmi'].isna() & df['stroke']==1]['id'])

# %% [markdown]
# #### As we saw in the class, there are different ways of dealing with missing data:
#
#
# *   We can Google for missing specs and fill the table with accurate data
# *   Estimate the missing data and fill Null values
# *   Drop the not so important columns
# *   Drop the rows containing missing values.
#
# The first step is obviously the most accurate, but it usually takes time.

# %% [markdown]
# We have one children (girl) among these 40 people that should use google for check the bmi for 1-year children.

# %% [markdown]
# Baseod on [this](https://cdn.who.int/media/docs/default-source/child-growth/child-growth-standards/indicators/body-mass-index-for-age/cht-bfa-girls-p-0-2.pdf?sfvrsn=16aa7a98_17) and [this](https://cdn.who.int/media/docs/default-source/child-growth/child-growth-standards/indicators/body-mass-index-for-age/cht-bfa-girls-z-0-2.pdf?sfvrsn=3fe76a61_27), I put BMI = 16.5 for this young girl.

# %%
df.loc[df['id'] == 69768, 'bmi'] = 16.5
df[df['id'] == 69768]
# Out:
#         id  gender   age  hypertension  heart_disease ever_married work_type  \
# 162  69768  Female  1.32             0              0           No  children
#
#     Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 162          Urban              70.37  16.5        Unknown       1

# %% [markdown]
# For other, I put mean of bmi for them.

# %%
df.loc[df['bmi'].isna(), 'bmi'] = round(df['bmi'].mean(), 1)

# %%
df.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df[df['id'].isin(id_nan_bmi_list)]
# Out:
#         id  gender    age  hypertension  heart_disease ever_married  \
# 1    51676  Female  61.00             0              0          Yes
# 8    27419  Female  59.00             0              0          Yes
# 13    8213    Male  78.00             0              1          Yes
# 19   25226    Male  57.00             0              1           No
# 27   61843    Male  58.00             0              0          Yes
# 29   69160    Male  59.00             0              0          Yes
# 43    1845  Female  63.00             0              0          Yes
# 46   37937  Female  75.00             0              1           No
# 50   18587  Female  76.00             0              0           No
# 51   15102    Male  78.00             1              0          Yes
# 54    8752  Female  63.00             0              0          Yes
# 57   66400    Male  78.00             0              0          Yes
# 64    7356    Male  75.00             0              0          Yes
# 70   70676  Female  76.00             0              0          Yes
# 78   45805  Female  51.00             0              0          Yes
# 81   26015  Female  66.00             0              0          Yes
# 84   70042    Male  58.00             0              0          Yes
# 105   2346    Male  58.00             0              0          Yes
# 112  36706  Female  76.00             0              0          Yes
# 124  14164  Female  72.00             0              0          Yes
# 126   3352    Male  78.00             1              0          Yes
# 129  48796  Female  75.00             0              0          Yes
# 133  31563  Female  38.00             0              0          Yes
# 146  41241    Male  65.00             0              0          Yes
# 150  11933  Female  79.00             0              0          Yes
# 160  50931  Female  76.00             0              0          Yes
# 161  16590    Male  71.00             0              1          Yes
# 162  69768  Female   1.32             0              0           No
# 167  43364    Male  79.00             1              0          Yes
# 170  28939    Male  64.00             0              0          Yes
# 171  60739  Female  79.00             1              1           No
# 174  40899  Female  78.00             0              0          Yes
# 178  33486  Female  80.00             0              0          Yes
# 183   8003  Female  77.00             0              0           No
# 189  66955    Male  61.00             0              1          Yes
# 198  18937    Male  79.00             0              0          Yes
# 200  54695    Male  74.00             0              0          Yes
# 218  25904  Female  76.00             1              1          Yes
# 227  39105    Male  74.00             0              0          Yes
# 247  34060    Male  71.00             1              0          Yes
#
#          work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 1    Self-employed          Rural             202.21  28.9     never smoked
# 8          Private          Rural              76.15  28.9          Unknown
# 13         Private          Urban             219.84  28.9          Unknown
# 19        Govt_job          Urban             217.08  28.9          Unknown
# 27         Private          Rural             189.84  28.9          Unknown
# 29         Private          Rural             211.78  28.9  formerly smoked
# 43         Private          Urban              90.90  28.9  formerly smoked
# 46   Self-employed          Urban             109.78  28.9          Unknown
# 50         Private          Urban              89.96  28.9          Unknown
# 51         Private          Urban              75.32  28.9  formerly smoked
# 54        Govt_job          Urban             197.54  28.9     never smoked
# 57         Private          Urban             237.75  28.9  formerly smoked
# 64         Private          Urban             104.72  28.9          Unknown
# 70        Govt_job          Rural              62.57  28.9  formerly smoked
# 78         Private          Urban             165.31  28.9     never smoked
# 81   Self-employed          Urban             101.45  28.9          Unknown
# 84         Private          Urban              71.20  28.9          Unknown
# 105        Private          Urban              82.30  28.9           smokes
# 112  Self-employed          Urban             106.41  28.9  formerly smoked
# 124        Private          Urban             219.91  28.9          Unknown
# 126  Self-employed          Urban              93.13  28.9  formerly smoked
# 129       Govt_job          Urban              62.48  28.9          Unknown
# 133        Private          Rural             101.45  28.9  formerly smoked
# 146  Self-employed          Urban              68.43  28.9  formerly smoked
# 150        Private          Rural             169.67  28.9          Unknown
# 160        Private          Urban              57.92  28.9  formerly smoked
# 161        Private          Urban              81.76  28.9           smokes
# 162       children          Urban              70.37  16.5          Unknown
# 167        Private          Rural              75.02  28.9     never smoked
# 170  Self-employed          Rural             111.98  28.9  formerly smoked
# 171  Self-employed          Rural              60.94  28.9     never smoked
# 174  Self-employed          Rural              60.67  28.9  formerly smoked
# 178       Govt_job          Urban             110.66  28.9          Unknown
# 183        Private          Urban              81.32  28.9          Unknown
# 189        Private          Urban             209.86  28.9          Unknown
# 198        Private          Rural             114.77  28.9  formerly smoked
# 200        Private          Urban             167.13  28.9          Unknown
# 218  Self-employed          Urban             199.86  28.9           smokes
# 227  Self-employed          Rural              60.98  28.9     never smoked
# 247  Self-employed          Rural              87.80  28.9          Unknown
#
#      stroke
# 1         1
# 8         1
# 13        1
# 19        1
# 27        1
# 29        1
# 43        1
# 46        1
# 50        1
# 51        1
# 54        1
# 57        1
# 64        1
# 70        1
# 78        1
# 81        1
# 84        1
# 105       1
# 112       1
# 124       1
# 126       1
# 129       1
# 133       1
# 146       1
# 150       1
# 160       1
# 161       1
# 162       1
# 167       1
# 170       1
# 171       1
# 174       1
# 178       1
# 183       1
# 189       1
# 198       1
# 200       1
# 218       1
# 227       1
# 247       1

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64

# %%
df[df['gender'] == 'Other']
# Out:
#          id gender   age  hypertension  heart_disease ever_married work_type  \
# 3116  56156  Other  26.0             0              0           No   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 3116          Rural             143.33  22.4  formerly smoked       0

# %%
df = df[df['id'] != 56156]

# %%
df.shape
# Out:
# (5109, 12)

# %% [markdown]
# Now, we do not have any missing values.

# %% [markdown]
# #### Invalid Data

# %% [markdown]
# This step usually involves checking for unusual patterns in the data. A good starting point would be to go over each column, and see if we can come up with a reasonable range for the values, and then check to see if there are data points out of that range

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5109.000000  5109.000000   5109.000000    5109.000000
# mean   36513.985516    43.229986      0.097475       0.054022
# std    21162.008804    22.613575      0.296633       0.226084
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17740.000000    25.000000      0.000000       0.000000
# 50%    36922.000000    45.000000      0.000000       0.000000
# 75%    54643.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5109.000000  5109.000000  5109.000000
# mean          106.140399    28.892347     0.048738
# std            45.285004     7.700188     0.215340
# min            55.120000    10.300000     0.000000
# 25%            77.240000    23.800000     0.000000
# 50%            91.880000    28.400000     0.000000
# 75%           114.090000    32.800000     0.000000
# max           271.740000    97.600000     1.000000

# %% [markdown]
# We can observe that:
# * 'id' column: It is not too important and maybe we can drop it.
# * 'age' column: It seems ok. maximum is 82 and minimum is 0.08 that maybe it is for a children but we should check it.
# * 'hypertension' column: It seems ok. All are boolean between one and zero but we should be sure of that.
# * 'heart_disease' column: It seems ok.Like last column.
# * 'avg_glucose_level' column: should check the net for its range.
# * 'bmi' level: The minimum is 10.3 that is a little low and maybe for a children. But the maximum is too high and maybe it can be an invalid.
# * 'stroke' column: Same as other boolean columns.
#
# * Also we have another columns that should explore (Like work_type)

# %% [markdown]
# Age Column:

# %%
df[df['age'] < 10].shape
# Out:
# (472, 12)

# %%
df[(df['age'] < 14) & (df['work_type'] != 'children')].shape
# Out:
# (15, 12)

# %% [markdown]
# Oops!, let's look more:

# %%
df[(df['age'] < 14) & (df['work_type'] != 'children')]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 251   16523  Female   8.0             0              0           No
# 410   54975    Male   7.0             0              0           No
# 455    7351    Male  13.0             0              0           No
# 939   16556    Male  13.0             0              0           No
# 1063  42821  Female  13.0             0              0           No
# 1789  13862  Female  13.0             0              0           No
# 1809  18179    Male  13.0             0              0           No
# 1976  46577  Female  13.0             0              0           No
# 2112   9199    Male  13.0             0              0           No
# 3334  56282    Male  13.0             0              0           No
# 3414  60249    Male  13.0             0              0           No
# 3486  70833  Female  13.0             0              0           No
# 3532  29613  Female  13.0             0              0           No
# 3964  38132  Female  13.0             0              0           No
# 4410  34900    Male  13.0             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 251         Private          Urban             110.89  17.6          Unknown
# 410   Self-employed          Rural              64.06  18.9          Unknown
# 455         Private          Urban              92.14  23.2     never smoked
# 939    Never_worked          Rural             111.48  20.8          Unknown
# 1063        Private          Rural              60.69  24.0           smokes
# 1789   Never_worked          Urban              70.93  22.9     never smoked
# 1809        Private          Rural              99.44  21.0     never smoked
# 1976        Private          Urban              77.63  31.7     never smoked
# 2112  Self-employed          Urban              74.19  31.1  formerly smoked
# 3334        Private          Rural              90.60  16.9     never smoked
# 3414        Private          Urban             141.09  24.0          Unknown
# 3486        Private          Urban              62.57  20.9          Unknown
# 3532        Private          Rural              73.76  26.7          Unknown
# 3964        Private          Rural             172.27  16.6     never smoked
# 4410   Never_worked          Urban              85.08  14.6          Unknown
#
#       stroke
# 251        0
# 410        0
# 455        0
# 939        0
# 1063       0
# 1789       0
# 1809       0
# 1976       0
# 2112       0
# 3334       0
# 3414       0
# 3486       0
# 3532       0
# 3964       0
# 4410       0

# %% [markdown]
# For id = 54975 and id = 9199 looks suspicious that a  7-year boy or 13-year boy is a self-employed. Let's explore more for under 18 people:

# %%
df[(df['age'] < 14) & (~df['work_type'].isin(['children', 'Private', 'Never_worked']))]
# Out:
#          id gender   age  hypertension  heart_disease ever_married  \
# 410   54975   Male   7.0             0              0           No
# 2112   9199   Male  13.0             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 410   Self-employed          Rural              64.06  18.9          Unknown
# 2112  Self-employed          Urban              74.19  31.1  formerly smoked
#
#       stroke
# 410        0
# 2112       0

# %% [markdown]
# Ok. In my opinio these two datas should be dropped because they are not normal.

# %%
df.drop(df[(df['age'] < 14) & (~df['work_type'].isin(['children', 'Private', 'Never_worked']))].index, inplace=True)
# Out:
# <ipython-input-409-8b2c8d1f8daf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[(df['age'] < 14) & (~df['work_type'].isin(['children', 'Private', 'Never_worked']))].index, inplace=True)

# %%
df[(df['age'] < 14) & (~df['work_type'].isin(['children', 'Private', 'Never_worked']))]
# Out:
# Empty DataFrame
# Columns: [id, gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %% [markdown]
# Now for older:

# %%
df[(df['age'] > 50) & (df['work_type'].isin(['children', 'Never_worked']))]
# Out:
# Empty DataFrame
# Columns: [id, gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
df[df['age'] > 30]['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job'], dtype=object)

# %% [markdown]
# Now everything about 'age' column is normal.

# %% [markdown]
# hypertension, heart_disease, stroke Columns:

# %%
df['hypertension'].unique()
# Out:
# array([0, 1])

# %%
df['heart_disease'].unique()
# Out:
# array([1, 0])

# %%
df['ever_married'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['stroke'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# Everything is ok for them. Just for ever_married we can check it woth age column:

# %%
df[(df['age'] < 18) & (df['ever_married'] == 'Yes')].shape
# Out:
# (0, 12)

# %% [markdown]
# Normal.

# %% [markdown]
# work_type Column:

# %%
df['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children', 'Never_worked'],
#       dtype=object)

# %%
df['work_type'].value_counts()
# Out:
# work_type
# Private          2924
# Self-employed     817
# children          687
# Govt_job          657
# Never_worked       22
# Name: count, dtype: int64

# %% [markdown]
# Normal.

# %% [markdown]
# Residence_type Column:

# %%
df['Residence_type'].value_counts()
# Out:
# Residence_type
# Urban    2595
# Rural    2512
# Name: count, dtype: int64

# %% [markdown]
# avg_glucose_level Column:

# %% [markdown]
# According to experts here are some range of blood sugar:
# A amount less than 50mg/dL means blood sugar is critically low and requires immediate treatment.
# - 51-70 means blood sugar is below normal levels and requires treatment.
# - 71-90 means blood sugar should be monitored and treated as necessary.
# - 90-180 means Healthy range.
# - 180-250 means above normal levels.
# - Higher than 250 means very high and requires immediate treatment

# %%
df['avg_glucose_level'].describe()
# Out:
# count    5107.000000
# mean      106.154895
# std        45.287834
# min        55.120000
# 25%        77.270000
# 50%        91.890000
# 75%       114.090000
# max       271.740000
# Name: avg_glucose_level, dtype: float64

# %%
df[df['avg_glucose_level'] >= 180].shape[0]/len(df)*100
# Out:
# 11.415703935774427

# %% [markdown]
# The people who have higher than 180mg/dL blood sugar makes up 11 % of total dataset.

# %%
high_glucose = df[df['avg_glucose_level'] >= 180]
high_glucose[high_glucose['stroke'] == 1].shape[0] / len(df[df['stroke'] == 1]) * 100
# Out:
# 31.72690763052209

# %% [markdown]
# Those 11% of people who have higher than 180mg/DL account for 32% of all strokes.

# %%
df[df['avg_glucose_level'] > 250]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 33    54401    Male  80.0             0              1          Yes
# 122   13491    Male  80.0             0              0          Yes
# 135   71279  Female  71.0             0              0          Yes
# 193   69112    Male  68.0             1              1          Yes
# 220   20463    Male  81.0             1              1          Yes
# 386   63732    Male  70.0             1              0          Yes
# 755   33585  Female  64.0             0              0          Yes
# 785   17813  Female  69.0             0              1          Yes
# 1067  55862    Male  67.0             1              1          Yes
# 1113  38678  Female  66.0             0              0          Yes
# 1207  22440  Female  49.0             0              0          Yes
# 1453   4692  Female  74.0             0              0          Yes
# 1529  34496  Female  82.0             0              0          Yes
# 2462  27626  Female  60.0             0              0           No
# 2693  20165  Female  77.0             0              0          Yes
# 2751  19209  Female  48.0             0              0          Yes
# 3088  26267  Female  76.0             0              0          Yes
# 3215  21534    Male  67.0             0              0          Yes
# 3393  13155  Female  67.0             1              0          Yes
# 4283  43656    Male  59.0             1              0          Yes
# 4356  52681  Female  39.0             0              0          Yes
# 4457  50070  Female  62.0             1              0          Yes
# 4470  47802    Male  28.0             0              0           No
# 4983  10995    Male  76.0             1              0          Yes
# 5034  65405  Female  79.0             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 33    Self-employed          Urban             252.72  30.5  formerly smoked
# 122         Private          Rural             259.63  31.7           smokes
# 135        Govt_job          Urban             263.32  38.7     never smoked
# 193         Private          Rural             271.74  31.1           smokes
# 220         Private          Urban             250.89  28.1           smokes
# 386   Self-employed          Urban             251.60  27.1     never smoked
# 755         Private          Rural             250.20  27.4          Unknown
# 785         Private          Rural             254.60  21.7          Unknown
# 1067        Private          Rural             254.63  31.0     never smoked
# 1113  Self-employed          Rural             251.46  35.2           smokes
# 1207        Private          Urban             267.76  29.3  formerly smoked
# 1453       Govt_job          Urban             251.99  25.5     never smoked
# 1529        Private          Urban             253.16  47.5          Unknown
# 2462       Govt_job          Rural             266.59  25.5     never smoked
# 2693        Private          Urban             250.80  32.9     never smoked
# 2751       Govt_job          Rural             255.17  38.1  formerly smoked
# 3088  Self-employed          Urban             267.61  27.9           smokes
# 3215        Private          Urban             260.85  28.9          Unknown
# 3393       Govt_job          Rural             263.56  26.3     never smoked
# 4283       Govt_job          Rural             253.93  28.9  formerly smoked
# 4356        Private          Urban             254.95  35.5           smokes
# 4457  Self-employed          Rural             261.67  43.0  formerly smoked
# 4470        Private          Urban             256.74  23.4  formerly smoked
# 4983        Private          Rural             267.60  30.5     never smoked
# 5034        Private          Urban             253.86  28.8  formerly smoked
#
#       stroke
# 33         1
# 122        1
# 135        1
# 193        1
# 220        1
# 386        0
# 755        0
# 785        0
# 1067       0
# 1113       0
# 1207       0
# 1453       0
# 1529       0
# 2462       0
# 2693       0
# 2751       0
# 3088       0
# 3215       0
# 3393       0
# 4283       0
# 4356       0
# 4457       0
# 4470       0
# 4983       0
# 5034       0

# %% [markdown]
# Seems normal.

# %% [markdown]
# bmi Column:

# %%
df['bmi'].describe()
# Out:
# count    5107.000000
# mean       28.893871
# std         7.700364
# min        10.300000
# 25%        23.800000
# 50%        28.400000
# 75%        32.800000
# max        97.600000
# Name: bmi, dtype: float64

# %% [markdown]
# - Underweight. Less than 18.5.
# - Healthy Weight. 18.5 to less than 25.
# - Overweight. 25 to less than 30.
# - Obesity. 30 or greater.
# - Class 1 Obesity. 30 to less than 35.
# - Class 2 Obesity. 35 to less than 40.
# - Class 3 Obesity. (Severe Obesity) 40 or greater.

# %% [markdown]
# We have some suspicious data here!

# %%
df[df['bmi'] > 60].shape
# Out:
# (13, 12)

# %%
df[df['bmi'] > 60]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 270   72911  Female  57.0             1              0          Yes
# 358   66333    Male  52.0             0              0          Yes
# 466    1307  Female  61.0             1              0          Yes
# 544     545    Male  42.0             0              0          Yes
# 928   41097  Female  23.0             1              0           No
# 1559  37759  Female  53.0             0              0          Yes
# 2128  56420    Male  17.0             1              0           No
# 2764  20292  Female  24.0             0              0          Yes
# 2840  65895  Female  52.0             0              0          Yes
# 3825  72784  Female  52.0             0              0          Yes
# 4188  70670  Female  27.0             0              0          Yes
# 4209  51856    Male  38.0             1              0          Yes
# 4838   5131  Female  51.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 270         Private          Rural             129.54  60.9         smokes
# 358   Self-employed          Urban              78.40  64.8   never smoked
# 466         Private          Rural             170.05  60.2         smokes
# 544         Private          Rural             210.48  71.9   never smoked
# 928         Private          Urban              70.03  78.0         smokes
# 1559        Private          Rural              72.63  66.8        Unknown
# 2128        Private          Rural              61.67  97.6        Unknown
# 2764        Private          Urban              85.55  63.3   never smoked
# 2840        Private          Urban              98.27  61.2        Unknown
# 3825        Private          Rural             118.46  61.6         smokes
# 4188        Private          Rural              57.96  64.4   never smoked
# 4209        Private          Rural              56.90  92.0   never smoked
# 4838        Private          Urban             107.72  60.9        Unknown
#
#       stroke
# 270        0
# 358        0
# 466        0
# 544        0
# 928        0
# 1559       0
# 2128       0
# 2764       0
# 2840       0
# 3825       0
# 4188       0
# 4209       0
# 4838       0

# %%
df[df['bmi'] < 12].shape
# Out:
# (3, 12)

# %%
df[df['bmi'] < 12]
# Out:
#          id  gender    age  hypertension  heart_disease ever_married  \
# 1609  38043  Female   1.24             0              0           No
# 2187  59993    Male  40.00             0              0          Yes
# 3307   3205  Female  79.00             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 1609       children          Rural             122.04  10.3        Unknown
# 2187        Private          Rural              60.96  11.5   never smoked
# 3307  Self-employed          Urban              79.03  11.3        Unknown
#
#       stroke
# 1609       0
# 2187       0
# 3307       0

# %%
df.boxplot(column=['bmi'])
# Out:
# <Axes: >

# %% [markdown]
# We have some outlier data that we can drop them:

# %%
df = df[~((df['bmi'] > 70) | (df['bmi'] < 11))]

# %%
df['bmi'].describe()
# Out:
# count    5102.000000
# mean       28.853626
# std         7.532788
# min        11.300000
# 25%        23.800000
# 50%        28.400000
# 75%        32.800000
# max        66.800000
# Name: bmi, dtype: float64

# %% [markdown]
# smoking_status Column:

# %%
df['smoking_status'].value_counts()
# Out:
# smoking_status
# never smoked       1890
# Unknown            1541
# formerly smoked     883
# smokes              788
# Name: count, dtype: int64

# %%
df[df['smoking_status'] == 'Unknown']
# Out:
#          id  gender   age  hypertension  heart_disease ever_married work_type  \
# 8     27419  Female  59.0             0              0          Yes   Private
# 9     60491  Female  78.0             0              0          Yes   Private
# 13     8213    Male  78.0             0              1          Yes   Private
# 19    25226    Male  57.0             0              1           No  Govt_job
# 23    64778    Male  82.0             0              1          Yes   Private
# ...     ...     ...   ...           ...            ...          ...       ...
# 5098    579    Male   9.0             0              0           No  children
# 5101  36901  Female  45.0             0              0          Yes   Private
# 5103  22127  Female  18.0             0              0           No   Private
# 5104  14180  Female  13.0             0              0           No  children
# 5109  44679  Female  44.0             0              0          Yes  Govt_job
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 8             Rural              76.15  28.9        Unknown       1
# 9             Urban              58.57  24.2        Unknown       1
# 13            Urban             219.84  28.9        Unknown       1
# 19            Urban             217.08  28.9        Unknown       1
# 23            Rural             208.30  32.5        Unknown       1
# ...             ...                ...   ...            ...     ...
# 5098          Urban              71.88  17.5        Unknown       0
# 5101          Urban              97.95  24.5        Unknown       0
# 5103          Urban              82.85  46.9        Unknown       0
# 5104          Rural             103.08  18.6        Unknown       0
# 5109          Urban              85.28  26.2        Unknown       0
#
# [1541 rows x 12 columns]

# %%
df[df['smoking_status'] == 'Unknown'].shape[0] / df.shape[0]
# Out:
# 0.30203841630733047

# %% [markdown]
# So, we won't remove 'Unknown' rows. But actually for children we can guess that the data should be 'never smoked' with probability of higher than 90%.

# %%
df[(df['smoking_status'] == 'Unknown') & (df['work_type'] == 'children')].shape
# Out:
# (617, 12)

# %% [markdown]
#  A lot of rows!

# %%
df[(df['smoking_status'] == 'Unknown') & (df['work_type'] == 'children')]
# Out:
#          id  gender    age  hypertension  heart_disease ever_married  \
# 162   69768  Female   1.32             0              0           No
# 245   49669  Female  14.00             0              0           No
# 249   30669    Male   3.00             0              0           No
# 282   33759  Female   3.00             0              0           No
# 290   55680    Male  13.00             0              0           No
# ...     ...     ...    ...           ...            ...          ...
# 5089  56714  Female   0.72             0              0           No
# 5094  28048    Male  13.00             0              0           No
# 5095  68598    Male   1.08             0              0           No
# 5098    579    Male   9.00             0              0           No
# 5104  14180  Female  13.00             0              0           No
#
#      work_type Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 162   children          Urban              70.37  16.5        Unknown       1
# 245   children          Rural              57.93  30.9        Unknown       1
# 249   children          Rural              95.12  18.0        Unknown       0
# 282   children          Urban              73.74  16.0        Unknown       0
# 290   children          Urban             114.84  18.3        Unknown       0
# ...        ...            ...                ...   ...            ...     ...
# 5089  children          Rural              62.13  16.8        Unknown       0
# 5094  children          Urban              82.38  24.3        Unknown       0
# 5095  children          Rural              79.15  17.4        Unknown       0
# 5098  children          Urban              71.88  17.5        Unknown       0
# 5104  children          Rural             103.08  18.6        Unknown       0
#
# [617 rows x 12 columns]

# %% [markdown]
# Absoloutly a children with age under 10, is in never smoked type.(High probability)

# %%
df.loc[(df['smoking_status'] == 'Unknown') & (df['work_type'] == 'children') & (df['age'] < 10), 'smoking_status'] = 'never smoked'

# %%
df[(df['smoking_status'] == 'Unknown') & (df['work_type'] == 'children')].shape
# Out:
# (148, 12)

# %%
df[(df['smoking_status'] == 'Unknown') & (df['work_type'] == 'children')]['age'].describe()
# Out:
# count    148.000000
# mean      12.466216
# std        1.755131
# min       10.000000
# 25%       11.000000
# 50%       12.000000
# 75%       14.000000
# max       16.000000
# Name: age, dtype: float64

# %% [markdown]
# THe minimum is 10 and maximum is 16. I will not change the data for them but I hope all of them are in 'never smoked' category :))))).

# %% [markdown]
# This step is complete.

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5102.000000  5102.000000   5102.000000    5102.000000
# mean   36514.664249    43.261615      0.097021       0.054096
# std    21162.468087    22.606894      0.296015       0.226230
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36905.000000    45.000000      0.000000       0.000000
# 75%    54637.250000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5102.000000  5102.000000  5102.000000
# mean          106.156788    28.853626     0.048804
# std            45.273566     7.532788     0.215480
# min            55.120000    11.300000     0.000000
# 25%            77.290000    23.800000     0.000000
# 50%            91.890000    28.400000     0.000000
# 75%           114.080000    32.800000     0.000000
# max           271.740000    66.800000     1.000000

# %% [markdown]
# ## Dealing with duplicate data

# %% [markdown]
# First, we check to see if there are any duplicate rows.

# %%
df[df.duplicated()].shape
# Out:
# (0, 12)

# %% [markdown]
# We do not have any duplicated data. So, this step is complete too.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Next step in preparing our data would be to make all columns have numerical values, so that the machine learning algorithms are capable of reading and analyzing the data later.
#
# This means that we have to convert columns with values of the following types to numbers:
#
# - Categorical, e.g. vehicle types or sizes
# - Date
# - Boolean
# - Text

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df.select_dtypes(include = "object").columns
# Out:
# Index(['gender', 'ever_married', 'work_type', 'Residence_type',
#        'smoking_status'],
#       dtype='object')

# %% [markdown]
# For columns that have a lot of unique values, we use the Categorical encoding. For other columns that contain unique values have a limited range, we follow the One-hot-encoding. The main reason is not to increase the number of columns in our dataset too much (as one-hot-encoding creates new columns). But overall, both approaches can be used.
#
# For 'gender', 'ever_married', 'Residence_type' we use one-hot coding.
#
# For 'work_type' and 'smoking_status' we use categorical encoding.

# %% [markdown]
# #### Categorical Encoding

# %%
to_categorical_columns = ['work_type','smoking_status']
for column in to_categorical_columns:
  df[column] = df[column].astype('category').cat.codes
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  work_type  \
# 0   9046    Male  67.0             0              1          Yes          2
# 1  51676  Female  61.0             0              0          Yes          3
# 2  31112    Male  80.0             0              1          Yes          2
# 3  60182  Female  49.0             0              0          Yes          2
# 4   1665  Female  79.0             1              0          Yes          3
#
#   Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0          Urban             228.69  36.6               1       1
# 1          Rural             202.21  28.9               2       1
# 2          Rural             105.92  32.5               2       1
# 3          Urban             171.23  34.4               3       1
# 4          Rural             174.12  24.0               2       1

# %%
df[column].astype('category').cat.codes
# Out:
# 0       1
# 1       2
# 2       2
# 3       3
# 4       2
#        ..
# 5105    2
# 5106    2
# 5107    2
# 5108    1
# 5109    0
# Length: 5102, dtype: int8

# %% [markdown]
# #### One-hot-encoding

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type               int8
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status          int8
# stroke                 int64
# dtype: object

# %%
to_one_hot_columns = df.select_dtypes(include = "object").columns
for column in to_one_hot_columns:
    encoded_df = pd.get_dummies(df[column], dtype=int)  # Convert to int explicitly
    df = df.drop(columns=[column])  # Drop original categorical column
    df = pd.concat([df, encoded_df], axis=1)  # Concatenate one-hot encoded columns
df.head()
# Out:
#       id   age  hypertension  heart_disease  work_type  avg_glucose_level  \
# 0   9046  67.0             0              1          2             228.69
# 1  51676  61.0             0              0          3             202.21
# 2  31112  80.0             0              1          2             105.92
# 3  60182  49.0             0              0          2             171.23
# 4   1665  79.0             1              0          3             174.12
#
#     bmi  smoking_status  stroke  Female  Male  No  Yes  Rural  Urban
# 0  36.6               1       1       0     1   0    1      0      1
# 1  28.9               2       1       1     0   0    1      1      0
# 2  32.5               2       1       0     1   0    1      1      0
# 3  34.4               3       1       1     0   0    1      0      1
# 4  24.0               2       1       1     0   0    1      1      0

# %%
df.shape
# Out:
# (5102, 15)

# %% [markdown]
# As can be seen, we have several new columns now, which correspond to the one-hot-encoded columns.
#
# Now we drop all non-numerical columns (as we have encoded them) and check to make sure our data is all numeric.

# %%
non_numeric_columns = df.select_dtypes(include = "object").columns
df.drop(non_numeric_columns, axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5102 entries, 0 to 5109
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5102 non-null   int64
#  1   age                5102 non-null   float64
#  2   hypertension       5102 non-null   int64
#  3   heart_disease      5102 non-null   int64
#  4   work_type          5102 non-null   int8
#  5   avg_glucose_level  5102 non-null   float64
#  6   bmi                5102 non-null   float64
#  7   smoking_status     5102 non-null   int8
#  8   stroke             5102 non-null   int64
#  9   Female             5102 non-null   int64
#  10  Male               5102 non-null   int64
#  11  No                 5102 non-null   int64
#  12  Yes                5102 non-null   int64
#  13  Rural              5102 non-null   int64
#  14  Urban              5102 non-null   int64
# dtypes: float64(3), int64(10), int8(2)
# memory usage: 568.0 KB

# %% [markdown]
# ## Normalization/Stadardization

# %% [markdown]
# Our next step would be to "normalize" all the columns. This means we need to make sure that all columns have a **"similar"** range.
#
# There are several ways of accomplishing this step. Two of the most popular options are:
#
# - SatandardScaler: converts the data in a column so that it has a 0-mean and standard deviation of 1
# - MinMaxScaler: simply scales the data in a column so that maximim value is 1 and the minimum value is 0
#
# Note that we don't need scaling on the newly added one-hot-encoded columns, as the values are between 0 and 1 by definition.

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  work_type  avg_glucose_level  \
# 0   9046  67.0             0              1          2             228.69
# 1  51676  61.0             0              0          3             202.21
# 2  31112  80.0             0              1          2             105.92
# 3  60182  49.0             0              0          2             171.23
# 4   1665  79.0             1              0          3             174.12
#
#     bmi  smoking_status  stroke  Female  Male  No  Yes  Rural  Urban
# 0  36.6               1       1       0     1   0    1      0      1
# 1  28.9               2       1       1     0   0    1      1      0
# 2  32.5               2       1       0     1   0    1      1      0
# 3  34.4               3       1       1     0   0    1      0      1
# 4  24.0               2       1       1     0   0    1      1      0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

standard_scaling_columns = ['age','work_type','avg_glucose_level']      # Specify the columns to standard scale
df[standard_scaling_columns] = scaler.fit_transform(df[standard_scaling_columns])
df[standard_scaling_columns].describe()
# Out:
#                 age     work_type  avg_glucose_level
# count  5.102000e+03  5.102000e+03       5.102000e+03
# mean  -1.225554e-16 -6.267037e-17       2.339694e-16
# std    1.000098e+00  1.000098e+00       1.000098e+00
# min   -1.910296e+00 -1.987149e+00      -1.127408e+00
# 25%   -8.078688e-01 -1.533000e-01      -6.376705e-01
# 50%    7.690377e-02 -1.533000e-01      -3.151549e-01
# 75%    7.847219e-01  7.636245e-01       1.750246e-01
# max    1.713733e+00  1.680549e+00       3.657751e+00

# %% [markdown]
# As we see in the above summary, the mean of all selected columns are 0 and the satndard deviation is 1.
#
# Now let's move to MinMax scaling for the other set of columns.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

minmax_scaling_columns = ['bmi', 'smoking_status']    # Specify the columns to scale using the min/max method
df[minmax_scaling_columns] = scaler.fit_transform(df[minmax_scaling_columns])
df[minmax_scaling_columns].describe()
# Out:
#                bmi  smoking_status
# count  5102.000000     5102.000000
# mean      0.316282        0.520384
# std       0.135726        0.329238
# min       0.000000        0.000000
# 25%       0.225225        0.333333
# 50%       0.308108        0.666667
# 75%       0.387387        0.666667
# max       1.000000        1.000000

# %%
df.describe()
# Out:
#                  id           age  hypertension  heart_disease     work_type  \
# count   5102.000000  5.102000e+03   5102.000000    5102.000000  5.102000e+03
# mean   36514.664249 -1.225554e-16      0.097021       0.054096 -6.267037e-17
# std    21162.468087  1.000098e+00      0.296015       0.226230  1.000098e+00
# min       67.000000 -1.910296e+00      0.000000       0.000000 -1.987149e+00
# 25%    17741.250000 -8.078688e-01      0.000000       0.000000 -1.533000e-01
# 50%    36905.000000  7.690377e-02      0.000000       0.000000 -1.533000e-01
# 75%    54637.250000  7.847219e-01      0.000000       0.000000  7.636245e-01
# max    72940.000000  1.713733e+00      1.000000       1.000000  1.680549e+00
#
#        avg_glucose_level          bmi  smoking_status       stroke  \
# count       5.102000e+03  5102.000000     5102.000000  5102.000000
# mean        2.339694e-16     0.316282        0.520384     0.048804
# std         1.000098e+00     0.135726        0.329238     0.215480
# min        -1.127408e+00     0.000000        0.000000     0.000000
# 25%        -6.376705e-01     0.225225        0.333333     0.000000
# 50%        -3.151549e-01     0.308108        0.666667     0.000000
# 75%         1.750246e-01     0.387387        0.666667     0.000000
# max         3.657751e+00     1.000000        1.000000     1.000000
#
#             Female         Male           No          Yes        Rural  \
# count  5102.000000  5102.000000  5102.000000  5102.000000  5102.000000
# mean      0.586437     0.413563     0.343199     0.656801     0.491572
# std       0.492520     0.492520     0.474824     0.474824     0.499978
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       1.000000     0.000000     0.000000     1.000000     0.000000
# 75%       1.000000     1.000000     1.000000     1.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#              Urban
# count  5102.000000
# mean      0.508428
# std       0.499978
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# ## Correlation Analysis

# %%
df.corr()
# Out:
#                          id       age  hypertension  heart_disease  work_type  \
# id                 1.000000  0.003912      0.002365      -0.001261  -0.015703
# age                0.003912  1.000000      0.278461       0.263711  -0.361205
# hypertension       0.002365  0.278461      1.000000       0.108964  -0.051464
# heart_disease     -0.001261  0.263711      0.108964       1.000000  -0.027922
# work_type         -0.015703 -0.361205     -0.051464      -0.027922   1.000000
# avg_glucose_level  0.002058  0.238043      0.176969       0.161979  -0.050447
# bmi                0.001786  0.336610      0.150133       0.041068  -0.305089
# smoking_status     0.007769 -0.033988      0.059158       0.009758  -0.018682
# stroke             0.006427  0.245171      0.128598       0.134841  -0.032222
# Female            -0.002085  0.027231     -0.020554      -0.085959  -0.056649
# Male               0.002085 -0.027231      0.020554       0.085959   0.056649
# No                -0.014326 -0.678640     -0.165813      -0.114469   0.352509
# Yes                0.014326  0.678640      0.165813       0.114469  -0.352509
# Rural              0.000832 -0.013506      0.007513      -0.002901   0.007078
# Urban             -0.000832  0.013506     -0.007513       0.002901  -0.007078
#
#                    avg_glucose_level       bmi  smoking_status    stroke  \
# id                          0.002058  0.001786        0.007769  0.006427
# age                         0.238043  0.336610       -0.033988  0.245171
# hypertension                0.176969  0.150133        0.059158  0.128598
# heart_disease               0.161979  0.041068        0.009758  0.134841
# work_type                  -0.050447 -0.305089       -0.018682 -0.032222
# avg_glucose_level           1.000000  0.175124        0.016522  0.132038
# bmi                         0.175124  1.000000        0.001353  0.039560
# smoking_status              0.016522  0.001353        1.000000 -0.009881
# stroke                      0.132038  0.039560       -0.009881  1.000000
# Female                     -0.055072  0.030439        0.022177 -0.009278
# Male                        0.055072 -0.030439       -0.022177  0.009278
# No                         -0.154633 -0.345273       -0.023650 -0.108173
# Yes                         0.154633  0.345273        0.023650  0.108173
# Rural                       0.004570 -0.001946       -0.014041 -0.015288
# Urban                      -0.004570  0.001946        0.014041  0.015288
#
#                      Female      Male        No       Yes     Rural     Urban
# id                -0.002085  0.002085 -0.014326  0.014326  0.000832 -0.000832
# age                0.027231 -0.027231 -0.678640  0.678640 -0.013506  0.013506
# hypertension      -0.020554  0.020554 -0.165813  0.165813  0.007513 -0.007513
# heart_disease     -0.085959  0.085959 -0.114469  0.114469 -0.002901  0.002901
# work_type         -0.056649  0.056649  0.352509 -0.352509  0.007078 -0.007078
# avg_glucose_level -0.055072  0.055072 -0.154633  0.154633  0.004570 -0.004570
# bmi                0.030439 -0.030439 -0.345273  0.345273 -0.001946  0.001946
# smoking_status     0.022177 -0.022177 -0.023650  0.023650 -0.014041  0.014041
# stroke            -0.009278  0.009278 -0.108173  0.108173 -0.015288  0.015288
# Female             1.000000 -1.000000 -0.030053  0.030053 -0.005400  0.005400
# Male              -1.000000  1.000000  0.030053 -0.030053  0.005400 -0.005400
# No                -0.030053  0.030053  1.000000 -1.000000  0.005993 -0.005993
# Yes                0.030053 -0.030053 -1.000000  1.000000 -0.005993  0.005993
# Rural             -0.005400  0.005400  0.005993 -0.005993  1.000000 -1.000000
# Urban              0.005400 -0.005400 -0.005993  0.005993 -1.000000  1.000000

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_216a8_row0_col0, #T_216a8_row1_col1, #T_216a8_row2_col2, #T_216a8_row3_col3, #T_216a8_row4_col4, #T_216a8_row5_col5, #T_216a8_row6_col6, #T_216a8_row7_col7, #T_216a8_row8_col8, #T_216a8_row9_col9, #T_216a8_row10_col10, #T_216a8_row11_col11, #T_216a8_row12_col12, #T_216a8_row13_col13, #T_216a8_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_216a8_row0_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_216a8_row0_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_216a8_row0_col3, #T_216a8_row0_col8, #T_216a8_row14_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_216a8_row0_col4, #T_216a8_row7_col4, #T_216a8_row8_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_216a8_row0_col5, #T_216a8_row6_col8, #T_216a8_row14_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_216a8_row0_col6, #T_216a8_row14_col4, #T_216a8_row14_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_216a8_row0_col7, #T_216a8_row3_col7, #T_216a8_row6_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_216a8_row0_col9, #T_216a8_row0_col14, #T_216a8_row2_col14, #T_216a8_row3_col13, #T_216a8_row4_col14, #T_216a8_row5_col14, #T_216a8_row6_col13, #T_216a8_row9_col13, #T_216a8_row10_col14, #T_216a8_row11_col14, #T_216a8_row12_col13, #T_216a8_row13_col9, #T_216a8_row13_col12, #T_216a8_row14_col10, #T_216a8_row14_col11 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_216a8_row0_col10, #T_216a8_row0_col13, #T_216a8_row2_col13, #T_216a8_row3_col14, #T_216a8_row4_col13, #T_216a8_row5_col13, #T_216a8_row6_col14, #T_216a8_row9_col14, #T_216a8_row10_col13, #T_216a8_row11_col13, #T_216a8_row12_col14, #T_216a8_row13_col10, #T_216a8_row13_col11, #T_216a8_row14_col9, #T_216a8_row14_col12 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_216a8_row0_col11, #T_216a8_row1_col13, #T_216a8_row7_col13, #T_216a8_row8_col9, #T_216a8_row8_col13 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_216a8_row0_col12, #T_216a8_row1_col6, #T_216a8_row1_col14, #T_216a8_row7_col14, #T_216a8_row8_col10, #T_216a8_row8_col14 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_216a8_row1_col0, #T_216a8_row2_col0, #T_216a8_row5_col0, #T_216a8_row6_col0, #T_216a8_row10_col0, #T_216a8_row13_col0, #T_216a8_row13_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_216a8_row1_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_216a8_row1_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_216a8_row1_col4, #T_216a8_row1_col7, #T_216a8_row4_col0, #T_216a8_row9_col10, #T_216a8_row10_col9, #T_216a8_row11_col0, #T_216a8_row11_col1, #T_216a8_row11_col2, #T_216a8_row11_col3, #T_216a8_row11_col5, #T_216a8_row11_col6, #T_216a8_row11_col8, #T_216a8_row11_col12, #T_216a8_row12_col11, #T_216a8_row13_col14, #T_216a8_row14_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_216a8_row1_col5 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_216a8_row1_col8 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_216a8_row1_col9, #T_216a8_row6_col9, #T_216a8_row7_col12, #T_216a8_row9_col12, #T_216a8_row10_col11, #T_216a8_row11_col10, #T_216a8_row12_col6, #T_216a8_row12_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_216a8_row1_col10, #T_216a8_row6_col10, #T_216a8_row7_col11, #T_216a8_row9_col11, #T_216a8_row10_col12, #T_216a8_row11_col9, #T_216a8_row12_col10 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_216a8_row1_col11 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_216a8_row1_col12 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_216a8_row2_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_216a8_row2_col3 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_216a8_row2_col4, #T_216a8_row5_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_216a8_row2_col5, #T_216a8_row3_col6, #T_216a8_row6_col5, #T_216a8_row8_col6 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_216a8_row2_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_216a8_row2_col7, #T_216a8_row4_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_216a8_row2_col8 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_216a8_row2_col9, #T_216a8_row7_col10 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_216a8_row2_col10, #T_216a8_row7_col9 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_216a8_row2_col11 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_216a8_row2_col12 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_216a8_row3_col0, #T_216a8_row4_col7, #T_216a8_row9_col0, #T_216a8_row14_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_216a8_row3_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_216a8_row3_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_216a8_row3_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_216a8_row3_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_216a8_row3_col8 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_216a8_row3_col9 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_216a8_row3_col10, #T_216a8_row5_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_216a8_row3_col11 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_216a8_row3_col12 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_216a8_row4_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_216a8_row4_col2, #T_216a8_row13_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_216a8_row4_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_216a8_row4_col6, #T_216a8_row12_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_216a8_row4_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_216a8_row4_col9, #T_216a8_row5_col9 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_216a8_row4_col10, #T_216a8_row5_col10 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_216a8_row4_col11 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_216a8_row4_col12 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_216a8_row5_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_216a8_row5_col3, #T_216a8_row8_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_216a8_row5_col6, #T_216a8_row10_col1 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_216a8_row5_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_216a8_row5_col8 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_216a8_row5_col11 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_216a8_row5_col12 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_216a8_row6_col1 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_216a8_row6_col2, #T_216a8_row13_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_216a8_row6_col3, #T_216a8_row13_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_216a8_row6_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_216a8_row6_col11 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_216a8_row6_col12 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_216a8_row7_col0, #T_216a8_row8_col0, #T_216a8_row8_col7 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_216a8_row7_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_216a8_row7_col2, #T_216a8_row12_col8 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_216a8_row7_col3, #T_216a8_row14_col8 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_216a8_row7_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_216a8_row7_col6, #T_216a8_row13_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_216a8_row7_col8, #T_216a8_row9_col5, #T_216a8_row9_col8 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_216a8_row8_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_216a8_row8_col3, #T_216a8_row9_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_216a8_row8_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_216a8_row8_col11 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_216a8_row8_col12 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_216a8_row9_col
