# %% [markdown]
# Dataset: [link](https://www.kaggle.com/CooperUnion/cardataset)

# %%
import pandas as pd

# %%
df = pd.read_csv('car_data.csv')

# %%
df.head(6) # default = 5
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
df.tail(3) # default = 5
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 11911  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11912  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11913                      Luxury      Midsize          Sedan           26
#
#        city mpg  Popularity   MSRP
# ...

# %%
df.shape
# Out:
# (11914, 16)

# %%
list(df.columns)
# Out:
# ['Make',
#  'Model',
#  'Year',
#  'Engine Fuel Type',
#  'Engine HP',
#  'Engine Cylinders',
#  'Transmission Type',
#  'Driven_Wheels',
#  'Number of Doors',
#  'Market Category',
#  'Vehicle Size',
#  'Vehicle Style',
#  'highway MPG',
#  'city mpg',
#  'Popularity',
#  'MSRP']

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.sort_values(by='Year', ascending=False)
# Out:
#                 Make                   Model  Year  Engine Fuel Type  \
# 7376      Mitsubishi         Outlander Sport  2017  regular unleaded
# 4885             Kia                   Forte  2017  regular unleaded
# 11342         Nissan              Versa Note  2017  regular unleaded
# 1682   Mercedes-Benz  B-Class Electric Drive  2017          electric
# 11343         Nissan              Versa Note  2017  regular unleaded
# ...              ...                     ...   ...               ...
# 8810             GMC                    S-15  1990  regular unleaded
# 9988          Nissan                  Stanza  1990  regular unleaded
# 9987          Nissan                  Stanza  1990  regular unleaded
# 11205         Nissan                     Van  1990  regular unleaded
# 674          Pontiac                    6000  1990  regular unleaded
#
#        Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# ...

# %%
df.sort_values(by='Year', ascending=False).sort_values(by='Popularity', ascending=True)
# Out:
#          Make                Model  Year                Engine Fuel Type  \
# 2118   Spyker                   C8  2009     premium unleaded (required)
# 2116   Spyker                   C8  2009     premium unleaded (required)
# 2117   Spyker                   C8  2009     premium unleaded (required)
# 5203  Genesis                  G80  2017  premium unleaded (recommended)
# 5202  Genesis                  G80  2017                regular unleaded
# ...       ...                  ...   ...                             ...
# 4406     Ford             Explorer  2017                regular unleaded
# 4407     Ford             Explorer  2017        flex-fuel (unleaded/E85)
# 3644     Ford                E-150  1996                regular unleaded
# 4347     Ford  Explorer Sport Trac  2008                regular unleaded
# 4487     Ford                F-150  2015        flex-fuel (unleaded/E85)
#
#       Engine HP  Engine Cylinders Transmission Type     Driven_Wheels  \
# ...

# %%
list_of_yrars = list(df.Year.unique())
list_of_yrars.sort()
list_of_yrars
# Out:
# [1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017]

# %%
df[['Year', 'Model', 'Popularity']]
# Out:
#        Year       Model  Popularity
# 0      2011  1 Series M        3916
# 1      2011    1 Series        3916
# 2      2011    1 Series        3916
# 3      2011    1 Series        3916
# 4      2011    1 Series        3916
# ...     ...         ...         ...
# 11909  2012         ZDX         204
# 11910  2012         ZDX         204
# 11911  2012         ZDX         204
# 11912  2013         ZDX         204
# 11913  2006      Zephyr          61
#
# [11914 rows x 3 columns]

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Difference between iloc and loc</title>
#     <style>
#         table {
#             width: 40%;
#             border-collapse: collapse;
#             margin: 20px 0;
#             font-size: 18px;
#             text-align: left;
#         }
#         th, td {
#             padding: 10px;
#             border: 1px solid black;
#         }
#         th {
#             background-color: #f2f2f2;
#         }
#         code {
#             background-color: #f4f4f4;
#             padding: 3px;
#             border-radius: 5px;
#         }
#     </style>
# </head>
# <body>
#     <h2>Difference between <code>iloc</code> and <code>loc</code> in Pandas</h2>
#     <table>
#         <tr>
#             <th>Feature</th>
#             <th>iloc</th>
#             <th>loc</th>
#         </tr>
#         <tr>
#             <td>Indexing Type</td>
#             <td>Integer-based</td>
#             <td>Label-based</td>
#         </tr>
#         <tr>
#             <td>Syntax</td>
#             <td><code>df.iloc[row_index, col_index]</code></td>
#             <td><code>df.loc[row_label, col_label]</code></td>
#         </tr>
#         <tr>
#             <td>Supports Slicing</td>
#             <td>Yes (integer indices)</td>
#             <td>Yes (label-based)</td>
#         </tr>
#         <tr>
#             <td>Works with Boolean Indexing</td>
#             <td>No</td>
#             <td>Yes</td>
#         </tr>
#     </table>
#
# <h3> Example: </h3>
# <pre>
# import pandas as pd
#
# data = {'A': [10, 20, 30], 'B': [40, 50, 60]}
# df = pd.DataFrame(data, index=['x', 'y', 'z'])
#
# ### Using iloc (integer positions)
# print(df.iloc[1, 0])  # Output: 20 (row index 1, column index 0)
#
# ### Using loc (label-based)
# print(df.loc['y', 'A'])  # Output: 20 (row 'y', column 'A')
# </pre>
# </body>
# </html>

# %%
df.iloc[:4]
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# ...

# %%
df.iloc[100:108]
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 100  Nissan  240SX  1997  regular unleaded      155.0               4.0
# 101  Nissan  240SX  1998  regular unleaded      155.0               4.0
# 102  Nissan  240SX  1998  regular unleaded      155.0               4.0
# 103  Nissan  240SX  1998  regular unleaded      155.0               4.0
# 104   Volvo    240  1991  regular unleaded      114.0               4.0
# 105   Volvo    240  1991  regular unleaded      114.0               4.0
# 106   Volvo    240  1991  regular unleaded      114.0               4.0
# 107   Volvo    240  1992  regular unleaded      114.0               4.0
#
#     Transmission Type     Driven_Wheels  Number of Doors Market Category  \
# 100            MANUAL  rear wheel drive              2.0     Performance
# 101            MANUAL  rear wheel drive              2.0     Performance
# 102            MANUAL  rear wheel drive              2.0     Performance
# ...

# %%
df.loc[100:108]
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 100  Nissan  240SX  1997  regular unleaded      155.0               4.0
# 101  Nissan  240SX  1998  regular unleaded      155.0               4.0
# 102  Nissan  240SX  1998  regular unleaded      155.0               4.0
# 103  Nissan  240SX  1998  regular unleaded      155.0               4.0
# 104   Volvo    240  1991  regular unleaded      114.0               4.0
# 105   Volvo    240  1991  regular unleaded      114.0               4.0
# 106   Volvo    240  1991  regular unleaded      114.0               4.0
# 107   Volvo    240  1992  regular unleaded      114.0               4.0
# 108   Volvo    240  1992  regular unleaded      114.0               4.0
#
#     Transmission Type     Driven_Wheels  Number of Doors Market Category  \
# 100            MANUAL  rear wheel drive              2.0     Performance
# 101            MANUAL  rear wheel drive              2.0     Performance
# ...

# %%
df.loc[100:108, ['Year', 'Transmission Type', 'Model']]
# Out:
#      Year Transmission Type  Model
# 100  1997            MANUAL  240SX
# 101  1998            MANUAL  240SX
# 102  1998            MANUAL  240SX
# 103  1998            MANUAL  240SX
# 104  1991            MANUAL    240
# 105  1991         AUTOMATIC    240
# 106  1991            MANUAL    240
# 107  1992            MANUAL    240
# 108  1992            MANUAL    240

# %%
df[df['Year'] >= 2015]
# Out:
#        Make       Model  Year                Engine Fuel Type  Engine HP  \
# 32     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 33     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 34     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 41      BMW    2 Series  2016     premium unleaded (required)      240.0
# 42      BMW    2 Series  2016     premium unleaded (required)      240.0
# ...     ...         ...   ...                             ...        ...
# 11898   BMW          Z4  2015     premium unleaded (required)      300.0
# 11899   BMW          Z4  2015     premium unleaded (required)      335.0
# 11900   BMW          Z4  2016     premium unleaded (required)      300.0
# 11901   BMW          Z4  2016     premium unleaded (required)      240.0
# 11902   BMW          Z4  2016     premium unleaded (required)      335.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %% [markdown]
# Now you will understand the difference between iloc and loc better:

# %%
df[df['Year'] >= 2015].iloc[32:42]
# Out:
#         Make Model  Year          Engine Fuel Type  Engine HP  \
# 76  Chrysler   200  2016  flex-fuel (unleaded/E85)      184.0
# 77  Chrysler   200  2016  flex-fuel (unleaded/E85)      184.0
# 78  Chrysler   200  2017  flex-fuel (unleaded/E85)      295.0
# 79  Chrysler   200  2017  flex-fuel (unleaded/E85)      295.0
# 80  Chrysler   200  2017  flex-fuel (unleaded/E85)      184.0
# 81  Chrysler   200  2017  flex-fuel (unleaded/E85)      184.0
# 82  Chrysler   200  2017  flex-fuel (unleaded/E85)      184.0
# 83  Chrysler   200  2017  flex-fuel (unleaded/E85)      295.0
# 84  Chrysler   200  2017  flex-fuel (unleaded/E85)      184.0
# 85  Chrysler   200  2017  flex-fuel (unleaded/E85)      184.0
#
#     Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 76               4.0         AUTOMATIC  front wheel drive              4.0
# 77               4.0         AUTOMATIC  front wheel drive              4.0
# ...

# %%
df[df['Year'] >= 2015].loc[32:42]
# Out:
#     Make       Model  Year                Engine Fuel Type  Engine HP  \
# 32  FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 33  FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 34  FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 41   BMW    2 Series  2016     premium unleaded (required)      240.0
# 42   BMW    2 Series  2016     premium unleaded (required)      240.0
#
#     Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 32               4.0            MANUAL  rear wheel drive              2.0
# 33               4.0            MANUAL  rear wheel drive              2.0
# 34               4.0            MANUAL  rear wheel drive              2.0
# 41               4.0         AUTOMATIC  rear wheel drive              2.0
# 42               4.0         AUTOMATIC  rear wheel drive              2.0
#
#        Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# ...

# %%
df[df['Year'] >= 2015].shape
# Out:
# (5995, 16)

# %%
df[(df['Year'] >= 2014) & ((df['Make'] == 'Ferrari') | (df['Make'] == 'FIAT'))]
# Out:
#          Make           Model  Year                Engine Fuel Type  \
# 32       FIAT      124 Spider  2017  premium unleaded (recommended)
# 33       FIAT      124 Spider  2017  premium unleaded (recommended)
# 34       FIAT      124 Spider  2017  premium unleaded (recommended)
# 468   Ferrari      458 Italia  2014     premium unleaded (required)
# 469   Ferrari      458 Italia  2014     premium unleaded (required)
# ...       ...             ...   ...                             ...
# 2169  Ferrari      California  2014     premium unleaded (required)
# 4645  Ferrari  F12 Berlinetta  2014     premium unleaded (required)
# 4646  Ferrari  F12 Berlinetta  2015     premium unleaded (required)
# 4667  Ferrari              FF  2014     premium unleaded (required)
# 4668  Ferrari              FF  2015     premium unleaded (required)
#
#       Engine HP  Engine Cylinders Transmission Type     Driven_Wheels  \
# 32        160.0               4.0            MANUAL  rear wheel drive
# ...

# %%
df[df['Make'].isin(['BMW', 'FIAT'])]
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
df[df['Year'].isin(['2016', '2014'])]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
df['Year'].dtype
# Out:
# dtype('int64')

# %%
df[df['Year'].isin([2016, 2014])].sort_values(by='Year', ascending=False)
# Out:
#             Make              Model  Year                Engine Fuel Type  \
# 41           BMW           2 Series  2016     premium unleaded (required)
# 7480  Volkswagen             Passat  2016                regular unleaded
# 7482  Volkswagen             Passat  2016                regular unleaded
# 7483  Volkswagen             Passat  2016                regular unleaded
# 7484  Volkswagen             Passat  2016                regular unleaded
# ...          ...                ...   ...                             ...
# 8277  Land Rover  Range Rover Sport  2014     premium unleaded (required)
# 3074       Honda               CR-Z  2014                regular unleaded
# 3073       Honda               CR-Z  2014                regular unleaded
# 3072       Honda               CR-Z  2014                regular unleaded
# 6029  Volkswagen          Jetta GLI  2014  premium unleaded (recommended)
#
#       Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# ...

# %%
df[df['Year'].isin([2016, 2014])].sort_values(by='Year', ascending=False).loc[41]
# Out:
# Make                                         BMW
# Model                                   2 Series
# Year                                        2016
# Engine Fuel Type     premium unleaded (required)
# Engine HP                                  240.0
# Engine Cylinders                             4.0
# Transmission Type                      AUTOMATIC
# Driven_Wheels                   rear wheel drive
# Number of Doors                              2.0
# Market Category               Luxury,Performance
# Vehicle Size                             Compact
# Vehicle Style                              Coupe
# highway MPG                                   35
# city mpg                                      23
# Popularity                                  3916
# MSRP                                       32850
# Name: 41, dtype: object

# %%
df[df['Year'].isin([2016, 2014])].sort_values(by='Year', ascending=False).iloc[41]
# Out:
# Make                            Toyota
# Model                          Prius c
# Year                              2016
# Engine Fuel Type      regular unleaded
# Engine HP                         99.0
# Engine Cylinders                   4.0
# Transmission Type            AUTOMATIC
# Driven_Wheels        front wheel drive
# Number of Doors                    4.0
# Market Category       Hatchback,Hybrid
# Vehicle Size                   Compact
# Vehicle Style            4dr Hatchback
# highway MPG                         46
# city mpg                            53
# Popularity                        2031
# MSRP                             21355
# Name: 7675, dtype: object

# %%
df[(df['Year'] >= 2015) & (df['Make'].isin(['Ferrari','Ford']) & ((df['Vehicle Size']=='Large') | (df['Vehicle Size']=='Compact') ) )]
# Out:
#           Make          Model  Year             Engine Fuel Type  Engine HP  \
# 471    Ferrari     458 Italia  2015  premium unleaded (required)      562.0
# 472    Ferrari     458 Italia  2015  premium unleaded (required)      562.0
# 473    Ferrari     458 Italia  2015  premium unleaded (required)      597.0
# 2095      Ford   C-Max Hybrid  2015             regular unleaded      188.0
# 2096      Ford   C-Max Hybrid  2015             regular unleaded      188.0
# ...        ...            ...   ...                          ...        ...
# 10731     Ford  Transit Wagon  2017     flex-fuel (unleaded/E85)      275.0
# 10732     Ford  Transit Wagon  2017             regular unleaded      275.0
# 10734     Ford  Transit Wagon  2017     flex-fuel (unleaded/E85)      275.0
# 10735     Ford  Transit Wagon  2017             regular unleaded      275.0
# 10738     Ford  Transit Wagon  2017             regular unleaded      275.0
#
# ...

# %%
df[df['Make']=='Ford']
# Out:
#        Make     Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 1331   Ford  Aerostar  1995  regular unleaded      135.0               6.0
# 1332   Ford  Aerostar  1995  regular unleaded      135.0               6.0
# 1333   Ford  Aerostar  1995  regular unleaded      155.0               6.0
# 1334   Ford  Aerostar  1995  regular unleaded      135.0               6.0
# 1335   Ford  Aerostar  1996  regular unleaded      140.0               6.0
# ...     ...       ...   ...               ...        ...               ...
# 11443  Ford  Windstar  2003  regular unleaded      200.0               6.0
# 11444  Ford  Windstar  2003  regular unleaded      200.0               6.0
# 11445  Ford  Windstar  2003  regular unleaded      200.0               6.0
# 11446  Ford  Windstar  2003  regular unleaded      200.0               6.0
# 11447  Ford  Windstar  2003  regular unleaded      200.0               6.0
#
# ...

# %%
list(df.Make.unique())
# Out:
# ['BMW',
#  'Audi',
#  'FIAT',
#  'Mercedes-Benz',
#  'Chrysler',
#  'Nissan',
#  'Volvo',
#  'Mazda',
#  'Mitsubishi',
#  'Ferrari',
#  'Alfa Romeo',
#  'Toyota',
#  'McLaren',
#  'Maybach',
#  'Pontiac',
#  'Porsche',
#  'Saab',
#  'GMC',
#  'Hyundai',
#  'Plymouth',
#  'Honda',
#  'Oldsmobile',
#  'Suzuki',
#  'Ford',
#  'Cadillac',
#  'Kia',
#  'Bentley',
#  'Chevrolet',
#  'Dodge',
#  'Lamborghini',
#  'Lincoln',
#  'Subaru',
#  'Volkswagen',
#  'Spyker',
#  'Buick',
#  'Acura',
#  'Rolls-Royce',
#  'Maserati',
#  'Lexus',
#  'Aston Martin',
#  'Land Rover',
#  'Lotus',
#  'Infiniti',
#  'Scion',
#  'Genesis',
#  'HUMMER',
#  'Tesla',
#  'Bugatti']

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df[df['Make'] == 'Mercedes-Benz'].shape
# Out:
# (353, 16)

# %%
df.loc[df['Make'] == 'Mercedes-Benz', 'Make'] = 'Benz'
df[df['Make'] == 'Benz'].shape
# Out:
# (353, 16)

# %%
df[df['Make'] == 'Benz']
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 35    Benz   190-Class  1991             regular unleaded      130.0
# 36    Benz   190-Class  1991             regular unleaded      158.0
# 37    Benz   190-Class  1992             regular unleaded      158.0
# 38    Benz   190-Class  1992             regular unleaded      130.0
# 39    Benz   190-Class  1993             regular unleaded      130.0
# ...    ...         ...   ...                          ...        ...
# 9690  Benz  SLS AMG GT  2014  premium unleaded (required)      583.0
# 9691  Benz  SLS AMG GT  2014  premium unleaded (required)      583.0
# 9692  Benz     SLS AMG  2011  premium unleaded (required)      563.0
# 9693  Benz     SLS AMG  2012  premium unleaded (required)      563.0
# 9694  Benz     SLS AMG  2012  premium unleaded (required)      563.0
#
#       Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
df[df['Make'] == 'BMW']['Make'] = 'Bayerische Motoren Werke AG'
df
# Out:
# C:\Users\AMIRRE~1\AppData\Local\Temp/ipykernel_16940/3798168539.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Make'] == 'BMW']['Make'] = 'Bayerische Motoren Werke AG'
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# ...

# %%
df.loc[df['Make'] == 'BMW', 'Make'] = 'Bayerische Motoren Werke AG'
df
# Out:
#                               Make       Model  Year  \
# 0      Bayerische Motoren Werke AG  1 Series M  2011
# 1      Bayerische Motoren Werke AG    1 Series  2011
# 2      Bayerische Motoren Werke AG    1 Series  2011
# 3      Bayerische Motoren Werke AG    1 Series  2011
# 4      Bayerische Motoren Werke AG    1 Series  2011
# ...                            ...         ...   ...
# 11909                        Acura         ZDX  2012
# 11910                        Acura         ZDX  2012
# 11911                        Acura         ZDX  2012
# 11912                        Acura         ZDX  2013
# 11913                      Lincoln      Zephyr  2006
#
#                      Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0         premium unleaded (required)      335.0               6.0
# 1         premium unleaded (required)      300.0               6.0
# 2         premium unleaded (required)      300.0               6.0
# ...

# %%
df[df['Make'].isin(['Bayerische Motoren Werke AG', 'Benz'])].shape
# Out:
# (687, 16)

# %%
df[df['Make'].isin(['BMW', 'Mercedes-Benz'])].shape
# Out:
# (0, 16)

# %%
df['MSRP'].mean()
# Out:
# 40594.737032063116

# %%
df['highway MPG'].mean()
# Out:
# 26.637485311398354

# %%
df['highway MPG'].max()
# Out:
# 354

# %%
df[df['highway MPG']==354]
# Out:
#       Make Model  Year                Engine Fuel Type  Engine HP  \
# 1119  Audi    A6  2017  premium unleaded (recommended)      252.0
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 1119               4.0  AUTOMATED_MANUAL  front wheel drive              4.0
#
#      Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 1119          Luxury      Midsize         Sedan          354        24
#
#       Popularity   MSRP
# 1119        3105  51600

# %%
df['Number of Doors'].max()
# Out:
# 4.0

# %%
df['Vehicle Style'].unique()
# Out:
# array(['Coupe', 'Convertible', 'Sedan', 'Wagon', '4dr Hatchback',
#        '2dr Hatchback', '4dr SUV', 'Passenger Minivan', 'Cargo Minivan',
#        'Crew Cab Pickup', 'Regular Cab Pickup', 'Extended Cab Pickup',
#        '2dr SUV', 'Cargo Van', 'Convertible SUV', 'Passenger Van'],
#       dtype=object)

# %%
df['Vehicle Style'].value_counts()
# Out:
# Vehicle Style
# Sedan                  3048
# 4dr SUV                2488
# Coupe                  1211
# Convertible             793
# 4dr Hatchback           702
# Crew Cab Pickup         681
# Extended Cab Pickup     623
# Wagon                   592
# 2dr Hatchback           506
# Passenger Minivan       417
# Regular Cab Pickup      392
# 2dr SUV                 138
# Passenger Van           128
# Cargo Van                95
# Cargo Minivan            71
# Convertible SUV          29
# Name: count, dtype: int64

# %%
df[df['Vehicle Style'] == 'Convertible SUV']
# Out:
#              Make                  Model  Year  \
# 3553   Land Rover               Defender  1997
# 7024       Nissan  Murano CrossCabriolet  2012
# 7025       Nissan  Murano CrossCabriolet  2013
# 7026       Nissan  Murano CrossCabriolet  2014
# 8265   Land Rover     Range Rover Evoque  2017
# 8267   Land Rover     Range Rover Evoque  2017
# 8965       Suzuki                Samurai  1993
# 8966       Suzuki                Samurai  1993
# 8967       Suzuki                Samurai  1994
# 8968       Suzuki                Samurai  1995
# 9181       Suzuki               Sidekick  1996
# 9182       Suzuki               Sidekick  1996
# 9189       Suzuki               Sidekick  1997
# 9191       Suzuki               Sidekick  1997
# 9192       Suzuki               Sidekick  1998
# 9197       Suzuki               Sidekick  1998
# 9199       Suzuki               Sidekick  1998
# 10575   Chevrolet                Tracker  2002
# 10579   Chevrolet                Tracker  2002
# ...

# %%
df.loc[df['Vehicle Style'] == 'Convertible SUV', 'Popularity'].mean()
# Out:
# 803.0344827586207

# %%
df[(df['Vehicle Style'] == 'Convertible SUV') & (df['Number of Doors'] > 2)] # So, all are 2-door cars.
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
df['Engine HP'].max()
# Out:
# 1001.0

# %%
df[df['Engine HP'] == 1001]
# Out:
#           Make        Model  Year             Engine Fuel Type  Engine HP  \
# 11362  Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
# 11363  Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
# 11364  Bugatti  Veyron 16.4  2009  premium unleaded (required)     1001.0
#
#        Engine Cylinders Transmission Type    Driven_Wheels  Number of Doors  \
# 11362              16.0  AUTOMATED_MANUAL  all wheel drive              2.0
# 11363              16.0  AUTOMATED_MANUAL  all wheel drive              2.0
# 11364              16.0  AUTOMATED_MANUAL  all wheel drive              2.0
#
#                Market Category Vehicle Size Vehicle Style  highway MPG  \
# 11362  Exotic,High-Performance      Compact         Coupe           14
# 11363  Exotic,High-Performance      Compact         Coupe           14
# 11364  Exotic,High-Performance      Compact         Coupe           14
#
#        city mpg  Popularity     MSRP
# ...

# %%
df['MSRP'].max()
# Out:
# 2065902

# %%
df.sort_values(by='MSRP', ascending=False).head(6)
# Out:
#               Make        Model  Year             Engine Fuel Type  Engine HP  \
# 11362      Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
# 11364      Bugatti  Veyron 16.4  2009  premium unleaded (required)     1001.0
# 8486   Lamborghini     Reventon  2008  premium unleaded (required)      650.0
# 11363      Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
# 6351       Maybach    Landaulet  2012  premium unleaded (required)      620.0
# 6350       Maybach    Landaulet  2011  premium unleaded (required)      620.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 11362              16.0  AUTOMATED_MANUAL   all wheel drive              2.0
# 11364              16.0  AUTOMATED_MANUAL   all wheel drive              2.0
# 8486               12.0  AUTOMATED_MANUAL   all wheel drive              2.0
# 11363              16.0  AUTOMATED_MANUAL   all wheel drive              2.0
# ...

# %%
df.groupby(['Year'])

# %%
df.groupby(['Year']).Popularity.mean()
# Out:
# Year
# 1990    1456.048780
# 1991    1457.592105
# 1992    1387.960452
# 1993    1281.344498
# 1994    1268.049080
# 1995    1733.940741
# 1996    1879.068702
# 1997    1941.971429
# 1998    1847.980519
# 1999    1586.375000
# 2000    1057.161017
# 2001    1204.851190
# 2002    1419.400000
# 2003    1395.012605
# 2004    1361.000000
# 2005    1297.492958
# 2006    1215.156098
# 2007    1171.652174
# 2008    1357.343840
# 2009    1487.817942
# 2010    1303.080537
# 2011    1102.596491
# 2012     992.689922
# 2013    1261.043716
# 2014    1325.235993
# 2015    1695.047005
# 2016    1717.722299
# 2017    1894.409472
# Name: Popularity, dtype: float64

# %%
df.groupby(['Year']).Popularity.mean().max()
# Out:
# 1941.9714285714285

# %%
df.groupby(['Year'])['Engine HP']

# %%
df.groupby(['Make', 'Model'])

# %%
df.groupby(['Make', 'Model']).head(1)
# Out:
#                               Make       Model  Year  \
# 0      Bayerische Motoren Werke AG  1 Series M  2011
# 1      Bayerische Motoren Werke AG    1 Series  2011
# 17                            Audi         100  1992
# 32                            FIAT  124 Spider  2017
# 35                            Benz   190-Class  1991
# ...                            ...         ...   ...
# 11890  Bayerische Motoren Werke AG        Z4 M  2007
# 11894  Bayerische Motoren Werke AG          Z4  2014
# 11903  Bayerische Motoren Werke AG          Z8  2001
# 11906                        Acura         ZDX  2011
# 11913                      Lincoln      Zephyr  2006
#
#                      Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0         premium unleaded (required)      335.0               6.0
# 1         premium unleaded (required)      300.0               6.0
# 17                   regular unleaded      172.0               6.0
# ...

# %%
df.groupby(['Make', 'Model']).count()
# Out:
#                   Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# Make  Model
# Acura CL             9                 9          9                 9
#       ILX           16                16         16                16
#       ILX Hybrid     2                 2          2                 2
#       Integra       24                24         24                24
#       Legend        16                16         16                16
# ...                ...               ...        ...               ...
# Volvo V90            1                 1          1                 1
#       XC             1                 1          1                 1
#       XC60          54                54         54                54
#       XC70          18                18         18                18
#       XC90          17                17         17                17
#
#                   Transmission Type  Driven_Wheels  Number of Doors  \
# Make  Model
# ...

# %%
df.groupby(['Make', 'Model']).describe()
# Out:
#                   Year                                                  \
#                  count         mean       std     min      25%     50%
# Make  Model
# Acura CL           9.0  2002.333333  0.866025  2001.0  2002.00  2003.0
#       ILX         16.0  2016.125000  0.806226  2015.0  2015.75  2016.0
#       ILX Hybrid   2.0  2014.000000  0.000000  2014.0  2014.00  2014.0
#       Integra     24.0  2000.208333  0.832971  1999.0  1999.75  2000.0
#       Legend      16.0  1994.062500  0.853913  1993.0  1993.00  1994.0
# ...                ...          ...       ...     ...      ...     ...
# Volvo V90          1.0  1998.000000       NaN  1998.0  1998.00  1998.0
#       XC           1.0  2002.000000       NaN  2002.0  2002.00  2002.0
#       XC60        54.0  2015.481481  0.665618  2015.0  2015.00  2015.0
#       XC70        18.0  2015.444444  0.704792  2014.0  2015.00  2016.0
#       XC90        17.0  2016.058824  0.899346  2014.0  2016.00  2016.0
#
# ...

# %%
list(df.groupby(['Make', 'Model']).Make.unique())
# Out:
# [array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Acura'], dtype=object),
#  array(['Alfa Romeo'], dtype=object),
#  array(['Aston Martin'], dtype=object),
#  array(['Aston Martin'], dtype=object),
#  array(['Aston Martin'], dtype=object),
#  array(['Aston Martin'], dtype=object),
#  array(['Aston Martin'], dtype=object),
#  array(['Aston Martin'], dtype=object),
#  array(['Aston Martin'], dtype=object),
# ...

# %%
df.groupby(['Make', 'Model']).get_group(('Volvo', 'V90'))
# Out:
#         Make Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 11181  Volvo   V90  1998  regular unleaded      181.0               6.0
#
#       Transmission Type     Driven_Wheels  Number of Doors Market Category  \
# 11181         AUTOMATIC  rear wheel drive              4.0          Luxury
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity  MSRP
# 11181      Midsize         Wagon           23        16         870  2200

# %%
volvo_group = df[df['Make'] == 'Volvo'].groupby('Model')
print(volvo_group.head(5))
for name, group in volvo_group:
    print(f"Model: {name}")
    print(group)
# Out:
#         Make Model  Year                Engine Fuel Type  Engine HP  \
# 104    Volvo   240  1991                regular unleaded      114.0
# 105    Volvo   240  1991                regular unleaded      114.0
# 106    Volvo   240  1991                regular unleaded      114.0
# 107    Volvo   240  1992                regular unleaded      114.0
# 108    Volvo   240  1992                regular unleaded      114.0
# ...      ...   ...   ...                             ...        ...
# 11624  Volvo  XC90  2014                regular unleaded      240.0
# 11625  Volvo  XC90  2016  premium unleaded (recommended)      250.0
# 11626  Volvo  XC90  2016  premium unleaded (recommended)      316.0
# 11627  Volvo  XC90  2016  premium unleaded (recommended)      250.0
# 11640  Volvo    XC  2002     premium unleaded (required)      197.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
df.groupby(['Make']).MSRP.plot(kind='bar', figsize=(18, 8))
# Out:
# Make
# Acura                          AxesSubplot(0.125,0.125;0.775x0.755)
# Alfa Romeo                     AxesSubplot(0.125,0.125;0.775x0.755)
# Aston Martin                   AxesSubplot(0.125,0.125;0.775x0.755)
# Audi                           AxesSubplot(0.125,0.125;0.775x0.755)
# Bayerische Motoren Werke AG    AxesSubplot(0.125,0.125;0.775x0.755)
# Bentley                        AxesSubplot(0.125,0.125;0.775x0.755)
# Benz                           AxesSubplot(0.125,0.125;0.775x0.755)
# Bugatti                        AxesSubplot(0.125,0.125;0.775x0.755)
# Buick                          AxesSubplot(0.125,0.125;0.775x0.755)
# Cadillac                       AxesSubplot(0.125,0.125;0.775x0.755)
# Chevrolet                      AxesSubplot(0.125,0.125;0.775x0.755)
# Chrysler                       AxesSubplot(0.125,0.125;0.775x0.755)
# Dodge                          AxesSubplot(0.125,0.125;0.775x0.755)
# FIAT                           AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %%
df.groupby(['Make']).MSRP.mean().plot(kind='bar', figsize=(18,8))
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
df.groupby(['Make'])['Engine HP'].mean().plot(kind='bar', figsize=(18,8))
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
df['Status'] = df['Year'].apply(lambda p: 'New' if p>=2014 else 'Old')

# %%
df.head(6)
# Out:
#                           Make       Model  Year             Engine Fuel Type  \
# 0  Bayerische Motoren Werke AG  1 Series M  2011  premium unleaded (required)
# 1  Bayerische Motoren Werke AG    1 Series  2011  premium unleaded (required)
# 2  Bayerische Motoren Werke AG    1 Series  2011  premium unleaded (required)
# 3  Bayerische Motoren Werke AG    1 Series  2011  premium unleaded (required)
# 4  Bayerische Motoren Werke AG    1 Series  2011  premium unleaded (required)
# 5  Bayerische Motoren Werke AG    1 Series  2012  premium unleaded (required)
#
#    Engine HP  Engine Cylinders Transmission Type     Driven_Wheels  \
# 0      335.0               6.0            MANUAL  rear wheel drive
# 1      300.0               6.0            MANUAL  rear wheel drive
# 2      300.0               6.0            MANUAL  rear wheel drive
# 3      230.0               6.0            MANUAL  rear wheel drive
# 4      230.0               6.0            MANUAL  rear wheel drive
# ...

# %%
df[df['Status'] == 'New'].shape
# Out:
# (6584, 17)

# %%
df[df['Status'] == 'Old'].shape
# Out:
# (5330, 17)

# %% [markdown]
# Merging and Concatenation <br>
# [Link](https://towardsdatascience.com/3-key-differences-between-merge-and-concat-functions-of-pandas-ab2bab224b59/)

# %%
df.shape
# Out:
# (11914, 17)

# %%
df1 = df[:6000]
df2 = df[6000:]

# %%
df1.shape
# Out:
# (6000, 17)

# %%
df2.shape
# Out:
# (5914, 17)

# %%
new_df = pd.concat([df1, df2], axis=0)
new_df.shape
# Out:
# (11914, 17)

# %%
new_df
# Out:
#                               Make       Model  Year  \
# 0      Bayerische Motoren Werke AG  1 Series M  2011
# 1      Bayerische Motoren Werke AG    1 Series  2011
# 2      Bayerische Motoren Werke AG    1 Series  2011
# 3      Bayerische Motoren Werke AG    1 Series  2011
# 4      Bayerische Motoren Werke AG    1 Series  2011
# ...                            ...         ...   ...
# 11909                        Acura         ZDX  2012
# 11910                        Acura         ZDX  2012
# 11911                        Acura         ZDX  2012
# 11912                        Acura         ZDX  2013
# 11913                      Lincoln      Zephyr  2006
#
#                      Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0         premium unleaded (required)      335.0               6.0
# 1         premium unleaded (required)      300.0               6.0
# 2         premium unleaded (required)      300.0               6.0
# ...

# %%
new_df = pd.concat([df1, df2], axis=1)
new_df.shape
# Out:
# (11914, 34)

# %%
new_df
# Out:
#                               Make       Model    Year  \
# 0      Bayerische Motoren Werke AG  1 Series M  2011.0
# 1      Bayerische Motoren Werke AG    1 Series  2011.0
# 2      Bayerische Motoren Werke AG    1 Series  2011.0
# 3      Bayerische Motoren Werke AG    1 Series  2011.0
# 4      Bayerische Motoren Werke AG    1 Series  2011.0
# ...                            ...         ...     ...
# 11909                          NaN         NaN     NaN
# 11910                          NaN         NaN     NaN
# 11911                          NaN         NaN     NaN
# 11912                          NaN         NaN     NaN
# 11913                          NaN         NaN     NaN
#
#                   Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0      premium unleaded (required)      335.0               6.0
# 1      premium unleaded (required)      300.0               6.0
# 2      premium unleaded (required)      300.0               6.0
# ...

# %%
new_df = pd.concat([df1.reset_index(drop=True), df2.reset_index(drop=True)], axis=1)
new_df.shape
# Out:
# (6000, 34)

# %%
new_df
# Out:
#                              Make       Model  Year  \
# 0     Bayerische Motoren Werke AG  1 Series M  2011
# 1     Bayerische Motoren Werke AG    1 Series  2011
# 2     Bayerische Motoren Werke AG    1 Series  2011
# 3     Bayerische Motoren Werke AG    1 Series  2011
# 4     Bayerische Motoren Werke AG    1 Series  2011
# ...                           ...         ...   ...
# 5995                     Infiniti         J30  1996
# 5996                     Infiniti         J30  1997
# 5997                     Infiniti         J30  1997
# 5998                     Infiniti         J30  1997
# 5999                     Infiniti         J30  1997
#
#                  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0     premium unleaded (required)      335.0               6.0
# 1     premium unleaded (required)      300.0               6.0
# 2     premium unleaded (required)      300.0               6.0
# 3     premium unleaded (required)      230.0               6.0
# ...

# %%
new_df = pd.concat([df2.reset_index(drop=True), df1.reset_index(drop=True)], axis=1)
new_df.shape
# Out:
# (6000, 34)

# %%
new_df
# Out:
#             Make      Model    Year                Engine Fuel Type  \
# 0     Volkswagen  Jetta GLI  2013.0  premium unleaded (recommended)
# 1     Volkswagen  Jetta GLI  2013.0  premium unleaded (recommended)
# 2     Volkswagen  Jetta GLI  2013.0  premium unleaded (recommended)
# 3     Volkswagen  Jetta GLI  2013.0  premium unleaded (recommended)
# 4     Volkswagen  Jetta GLI  2013.0  premium unleaded (recommended)
# ...          ...        ...     ...                             ...
# 5995         NaN        NaN     NaN                             NaN
# 5996         NaN        NaN     NaN                             NaN
# 5997         NaN        NaN     NaN                             NaN
# 5998         NaN        NaN     NaN                             NaN
# 5999         NaN        NaN     NaN                             NaN
#
#       Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# 0         210.0               4.0  AUTOMATED_MANUAL  front wheel drive
# ...

# %% [markdown]
# Lokok at their shapes to understand better:

# %%
pd.concat([df1.reset_index(drop=True), df2.reset_index(drop=True)], axis=1, join='inner')
# Out:
#                              Make       Model  Year  \
# 0     Bayerische Motoren Werke AG  1 Series M  2011
# 1     Bayerische Motoren Werke AG    1 Series  2011
# 2     Bayerische Motoren Werke AG    1 Series  2011
# 3     Bayerische Motoren Werke AG    1 Series  2011
# 4     Bayerische Motoren Werke AG    1 Series  2011
# ...                           ...         ...   ...
# 5909                        Honda     Insight  2013
# 5910                        Honda     Insight  2013
# 5911                        Honda     Insight  2013
# 5912                        Honda     Insight  2013
# 5913                        Honda     Insight  2013
#
#                  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0     premium unleaded (required)      335.0               6.0
# 1     premium unleaded (required)      300.0               6.0
# 2     premium unleaded (required)      300.0               6.0
# 3     premium unleaded (required)      230.0               6.0
# ...

# %%
pd.concat([df1.reset_index(drop=True), df2.reset_index(drop=True)], axis=1, join='outer')
# Out:
#                              Make       Model  Year  \
# 0     Bayerische Motoren Werke AG  1 Series M  2011
# 1     Bayerische Motoren Werke AG    1 Series  2011
# 2     Bayerische Motoren Werke AG    1 Series  2011
# 3     Bayerische Motoren Werke AG    1 Series  2011
# 4     Bayerische Motoren Werke AG    1 Series  2011
# ...                           ...         ...   ...
# 5995                     Infiniti         J30  1996
# 5996                     Infiniti         J30  1997
# 5997                     Infiniti         J30  1997
# 5998                     Infiniti         J30  1997
# 5999                     Infiniti         J30  1997
#
#                  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0     premium unleaded (required)      335.0               6.0
# 1     premium unleaded (required)      300.0               6.0
# 2     premium unleaded (required)      300.0               6.0
# 3     premium unleaded (required)      230.0               6.0
# ...

# %%
pd.concat([df1.reset_index(drop=True), df2.reset_index(drop=True)], axis=0, join='inner')
# Out:
#                              Make       Model  Year  \
# 0     Bayerische Motoren Werke AG  1 Series M  2011
# 1     Bayerische Motoren Werke AG    1 Series  2011
# 2     Bayerische Motoren Werke AG    1 Series  2011
# 3     Bayerische Motoren Werke AG    1 Series  2011
# 4     Bayerische Motoren Werke AG    1 Series  2011
# ...                           ...         ...   ...
# 5909                        Acura         ZDX  2012
# 5910                        Acura         ZDX  2012
# 5911                        Acura         ZDX  2012
# 5912                        Acura         ZDX  2013
# 5913                      Lincoln      Zephyr  2006
#
#                     Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0        premium unleaded (required)      335.0               6.0
# 1        premium unleaded (required)      300.0               6.0
# 2        premium unleaded (required)      300.0               6.0
# 3        premium unleaded (required)      230.0               6.0
# ...

# %%
pd.concat([df1.reset_index(drop=True), df2.reset_index(drop=True)], axis=0, join='outer')
# Out:
#                              Make       Model  Year  \
# 0     Bayerische Motoren Werke AG  1 Series M  2011
# 1     Bayerische Motoren Werke AG    1 Series  2011
# 2     Bayerische Motoren Werke AG    1 Series  2011
# 3     Bayerische Motoren Werke AG    1 Series  2011
# 4     Bayerische Motoren Werke AG    1 Series  2011
# ...                           ...         ...   ...
# 5909                        Acura         ZDX  2012
# 5910                        Acura         ZDX  2012
# 5911                        Acura         ZDX  2012
# 5912                        Acura         ZDX  2013
# 5913                      Lincoln      Zephyr  2006
#
#                     Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0        premium unleaded (required)      335.0               6.0
# 1        premium unleaded (required)      300.0               6.0
# 2        premium unleaded (required)      300.0               6.0
# 3        premium unleaded (required)      230.0               6.0
# ...

# %% [markdown]
# ---

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (6000, 17)
# (5914, 17)

# %%
df1.merge(df2, on='Model', how='inner')
# Out:
# Empty DataFrame
# Columns: [Make_x, Model, Year_x, Engine Fuel Type_x, Engine HP_x, Engine Cylinders_x, Transmission Type_x, Driven_Wheels_x, Number of Doors_x, Market Category_x, Vehicle Size_x, Vehicle Style_x, highway MPG_x, city mpg_x, Popularity_x, MSRP_x, Status_x, Make_y, Year_y, Engine Fuel Type_y, Engine HP_y, Engine Cylinders_y, Transmission Type_y, Driven_Wheels_y, Number of Doors_y, Market Category_y, Vehicle Size_y, Vehicle Style_y, highway MPG_y, city mpg_y, Popularity_y, MSRP_y, Status_y]
# Index: []
#
# [0 rows x 33 columns]

# %%
df1.merge(df2, on='Model', how='outer')
# Out:
#                             Make_x     Model  Year_x  \
# 0      Bayerische Motoren Werke AG  1 Series  2011.0
# 1      Bayerische Motoren Werke AG  1 Series  2011.0
# 2      Bayerische Motoren Werke AG  1 Series  2011.0
# 3      Bayerische Motoren Werke AG  1 Series  2011.0
# 4      Bayerische Motoren Werke AG  1 Series  2012.0
# ...                            ...       ...     ...
# 11909                          NaN        xD     NaN
# 11910                          NaN        xD     NaN
# 11911                          NaN        xD     NaN
# 11912                          NaN        xD     NaN
# 11913                          NaN        xD     NaN
#
#                 Engine Fuel Type_x  Engine HP_x  Engine Cylinders_x  \
# 0      premium unleaded (required)        300.0                 6.0
# 1      premium unleaded (required)        300.0                 6.0
# 2      premium unleaded (required)        230.0                 6.0
# ...

# %%
df1.merge(df2, on='Model', how='inner')
# Out:
# Empty DataFrame
# Columns: [Make_x, Model, Year_x, Engine Fuel Type_x, Engine HP_x, Engine Cylinders_x, Transmission Type_x, Driven_Wheels_x, Number of Doors_x, Market Category_x, Vehicle Size_x, Vehicle Style_x, highway MPG_x, city mpg_x, Popularity_x, MSRP_x, Status_x, Make_y, Year_y, Engine Fuel Type_y, Engine HP_y, Engine Cylinders_y, Transmission Type_y, Driven_Wheels_y, Number of Doors_y, Market Category_y, Vehicle Size_y, Vehicle Style_y, highway MPG_y, city mpg_y, Popularity_y, MSRP_y, Status_y]
# Index: []
#
# [0 rows x 33 columns]

# %%
df1.set_index('Transmission Type')
# Out:
#                                           Make       Model  Year  \
# Transmission Type
# MANUAL             Bayerische Motoren Werke AG  1 Series M  2011
# MANUAL             Bayerische Motoren Werke AG    1 Series  2011
# MANUAL             Bayerische Motoren Werke AG    1 Series  2011
# MANUAL             Bayerische Motoren Werke AG    1 Series  2011
# MANUAL             Bayerische Motoren Werke AG    1 Series  2011
# ...                                        ...         ...   ...
# AUTOMATIC                             Infiniti         J30  1996
# AUTOMATIC                             Infiniti         J30  1997
# AUTOMATIC                             Infiniti         J30  1997
# AUTOMATIC                             Infiniti         J30  1997
# AUTOMATIC                             Infiniti         J30  1997
#
#                               Engine Fuel Type  Engine HP  Engine Cylinders  \
# Transmission Type
# ...

# %%
df2.set_index('Transmission Type')
# Out:
#                          Make      Model  Year  \
# Transmission Type
# AUTOMATED_MANUAL   Volkswagen  Jetta GLI  2013
# MANUAL             Volkswagen  Jetta GLI  2013
# MANUAL             Volkswagen  Jetta GLI  2013
# AUTOMATED_MANUAL   Volkswagen  Jetta GLI  2013
# AUTOMATED_MANUAL   Volkswagen  Jetta GLI  2013
# ...                       ...        ...   ...
# AUTOMATIC               Acura        ZDX  2012
# AUTOMATIC               Acura        ZDX  2012
# AUTOMATIC               Acura        ZDX  2012
# AUTOMATIC               Acura        ZDX  2013
# AUTOMATIC             Lincoln     Zephyr  2006
#
#                                  Engine Fuel Type  Engine HP  \
# Transmission Type
# AUTOMATED_MANUAL   premium unleaded (recommended)      210.0
# MANUAL             premium unleaded (recommended)      200.0
# MANUAL             premium unleaded (recommended)      210.0
# AUTOMATED_MANUAL   premium unleaded (recommended)      210.0
# ...

# %%
df1.join(df2, lsuffix='_caller')
# Out:
#                       Make_caller Model_caller  Year_caller  \
# 0     Bayerische Motoren Werke AG   1 Series M         2011
# 1     Bayerische Motoren Werke AG     1 Series         2011
# 2     Bayerische Motoren Werke AG     1 Series         2011
# 3     Bayerische Motoren Werke AG     1 Series         2011
# 4     Bayerische Motoren Werke AG     1 Series         2011
# ...                           ...          ...          ...
# 5995                     Infiniti          J30         1996
# 5996                     Infiniti          J30         1997
# 5997                     Infiniti          J30         1997
# 5998                     Infiniti          J30         1997
# 5999                     Infiniti          J30         1997
#
#           Engine Fuel Type_caller  Engine HP_caller  Engine Cylinders_caller  \
# 0     premium unleaded (required)             335.0                      6.0
# 1     premium unleaded (required)             300.0                      6.0
# ...
